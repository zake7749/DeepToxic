# %%
import torch
import torch.nn as nn

from sotoxic.data_helper.data_transformer import DataTransformer
from sotoxic.data_helper.data_loader import DataLoader
from sotoxic.train.trainer import PyTorchModelTrainer
from sotoxic.config import dataset_config
# Out:
# /home/zake7749/.local/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
VOCAB_SIZE = 100000
MAX_SEQUENCE_LENGTH = 300
EMBEDDING_SIZE = 300

# %% [markdown]
# ## Prepare training and testing data

# %%
print("Loading the dataset")
data_transformer = DataTransformer(max_num_words=VOCAB_SIZE, max_sequence_length=MAX_SEQUENCE_LENGTH, char_level=False)
data_loader = DataLoader()
train_sequences, training_labels, test_sequences = data_transformer.prepare_data()
# Out:
# Loading the dataset
# Doing preprocessing...
# Preprocessed.

# %%
train_sequences[:20]
# Out:
# [[686,
#   76,
#   1,
#   132,
#   124,
#   173,
#   28,
#   705,
#   4324,
#   9378,
#   1162,
#   81,
#   350,
#   44,
#   81,
#   12,
#   13594,
#   50,
#   6507,
#   15,
#   59,
#   2539,
#   143,
#   3,
#   2736,
#   31,
#   111,
#   1190,
#   16065,
#   2418,
#   6,
#   51,
#   20,
#   12,
#   239,
#   1,
#   349,
#   29,
#   1,
#   46,
#   136,
#   3,
#   38,
#   3789,
#   85],
#  [337,
#   7768,
#   42,
#   2818,
#   14,
#   628,
#   3656,
#   3,
#   38,
#   4701,
#   2584,
#   22,
#   90,
#   46,
#   929,
#   3682,
#   987,
#   674,
#   10174],
#  [429,
#   363,
#   3,
#   38,
#   118,
#   12,
#   250,
#   2,
#   77,
#   291,
#   10,
#   50,
#   9,
#   14,
#   551,
#   8,
#   2391,
#   496,
#   478,
#   99,
#   6,
#   568,
#   2,
#   39,
#   314,
#   132,
#   364,
#   4,
#   28,
#   46,
#   42,
#   183,
#   2,
#   440,
#   58,
#   34,
#   1,
#   2227,
#   88,
#   1,
#   696,
#   474],
#  [58,
#   3,
#   134,
#   92,
#   56,
#   311,
#   1362,
#   15,
#   2063,
#   3,
#   5532,
#   23,
#   1,
#   109,
#   2330,
#   53,
#   18,
#   485,
#   15,
#   25,
#   5,
#   3714,
#   4,
#   1310,
#   4,
#   9973,
#   3,
#   64,
#   1,
#   273,
#   83,
#   115,
#   12893,
#   35,
#   9,
#   44,
#   16,
#   41,
#   11,
#   1,
#   1469,
#   131,
#   1245,
#   2128,
#   418,
#   1245,
#   304,
#   3,
#   40,
#   20,
#   9,
#   485,
#   15,
#   23,
#   48,
#   47,
#   290,
#   68,
#   108,
#   23,
#   7,
#   17,
#   56,
#   4271,
#   13,
#   2227,
#   305,
#   15,
#   273,
#   25,
#   101,
#   2,
#   20,
#   10,
#   198,
#   51,
#   194,
#   39,
#   72,
#   36,
#   525,
#   2,
#   18,
#   5,
#   6073,
#   15,
#   45,
#   13,
#   367,
#   35,
#   3,
#   604,
#   36,
#   83,
#   18,
#   5,
#   2118,
#   369,
#   5,
#   2841,
#   2937,
#   71,
#   10,
#   420,
#   11,
#   1,
#   478,
#   597,
#   1397,
#   95,
#   3085,
#   5259],
#  [7, 1690, 16, 28, 2776, 56, 1052, 7, 564, 37, 9, 15],
#  [2728, 29, 39, 19, 96, 79, 1, 2348, 96, 46],
#  [2525, 142, 7, 2077, 303, 15, 28, 135],
#  [21,
#   208,
#   2,
#   1,
#   3581,
#   43,
#   57,
#   350,
#   51,
#   20,
#   12,
#   20,
#   10,
#   119,
#   25,
#   7,
#   33,
#   18,
#   727],
#  [263,
#   23,
#   1,
#   252,
#   598,
#   24,
#   1406,
#   2,
#   7,
#   463,
#   3,
#   38,
#   12,
#   9317,
#   2,
#   332,
#   204,
#   11,
#   1,
#   1364,
#   44,
#   32,
#   2796,
#   15,
#   39,
#   13,
#   208,
#   3,
#   38,
#   1082,
#   1135,
#   9,
#   10,
#   18,
#   58,
#   1230,
#   35,
#   47,
#   40,
#   79,
#   10,
#   13,
#   450,
#   19,
#   5,
#   259,
#   3,
#   17,
#   57,
#   2,
#   1,
#   4881,
#   8619,
#   26,
#   10,
#   609,
#   5,
#   1275,
#   10,
#   652,
#   2,
#   2269,
#   8619,
#   55,
#   8,
#   5,
#   632,
#   7657,
#   9,
#   1003,
#   7,
#   48,
#   474,
#   36,
#   229,
#   18,
#   145,
#   303,
#   22,
#   3510,
#   11,
#   11416],
#  [11625, 15, 14, 218, 6, 55, 16, 1893, 2, 133, 4, 78106],
#  [281,
#   79,
#   906,
#   13,
#   65931,
#   90,
#   13,
#   1475,
#   65931,
#   3,
#   430,
#   1,
#   147,
#   2967,
#   9,
#   1,
#   147,
#   8,
#   86,
#   126,
#   173,
#   281,
#   79,
#   26,
#   36,
#   8,
#   48,
#   686,
#   25,
#   906,
#   19,
#   2,
#   76,
#   98,
#   79,
#   11,
#   45,
#   2640,
#   281,
#   79,
#   11,
#   764,
#   2,
#   1,
#   7834,
#   281,
#   79,
#   349,
#   7,
#   229,
#   65,
#   332,
#   74,
#   15,
#   1,
#   147,
#   684,
#   5,
#   464,
#   686,
#   25,
#   906,
#   13,
#   76,
#   197,
#   14,
#   147,
#   11,
#   409,
#   8,
#   1879,
#   22,
#   281,
#   79,
#   51,
#   107,
#   2,
#   1,
#   147,
#   684,
#   6,
#   77,
#   10,
#   2,
#   425,
#   5,
#   281,
#   79,
#   906,
#   23,
#   7,
#   17,
#   701,
#   61,
#   281,
#   79,
#   296,
#   394,
#   1409,
#   9,
#   7,
#   17,
#   2073,
#   1,
#   281,
#   79,
#   906,
#   15,
#   133,
#   45,
#   149,
#   7,
#   40,
#   129,
#   5,
#   153,
#   4,
#   147,
#   45,
#   7,
#   17,
#   592,
#   30,
#   1758,
#   15,
#   1,
#   28,
#   398,
#   158,
#   10,
#   8,
#   1772,
#   31,
#   1,
#   97,
#   308,
#   4,
#   56,
#   78,
#   7,
#   16,
#   1697,
#   11,
#   6,
#   80,
#   3163,
#   147,
#   29,
#   1,
#   3582,
#   872,
#   181,
#   9,
#   56,
#   281,
#   79,
#   344,
#   701,
#   143,
#   377,
#   83,
#   624,
#   6,
#   2534,
#   103,
#   27,
#   686,
#   33,
#   18,
#   140,
#   47,
#   702,
#   143,
#   44,
#   17,
#   57,
#   701,
#   19,
#   897,
#   15,
#   410,
#   13,
#   270,
#   113,
#   23,
#   7,
#   17,
#   56,
#   244,
#   51,
#   214,
#   84,
#   31,
#   1,
#   296,
#   249,
#   244,
#   128,
#   7,
#   46,
#   710,
#   6886,
#   112,
#   13,
#   65931,
#   90,
#   13,
#   1475,
#   65931,
#   3,
#   612,
#   9,
#   1,
#   736,
#   684,
#   507,
#   68,
#   12,
#   2129,
#   60,
#   322,
#   1,
#   166,
#   35,
#   1,
#   249,
#   663,
#   8,
#   2145,
#   23,
#   7,
#   67,
#   12,
#   447,
#   14,
#   736,
#   198,
#   80,
#   7,
#   33,
#   115,
#   2,
#   2129,
#   1,
#   2305,
#   4,
#   1,
#   249,
#   23,
#   7,
#   3671,
#   10,
#   29,
#   5,
#   387,
#   80,
#   5,
#   158,
#   2,
#   1,
#   387,
#   29,
#   55,
#   10,
#   24,
#   519,
#   785,
#   22,
#   5,
#   7553,
#   4,
#   9,
#   387,
#   625,
#   4,
#   79,
#   4,
#   98,
#   166,
#   8,
#   772,
#   1752,
#   99,
#   184,
#   23,
#   1,
#   249,
#   2178,
#   8,
#   254,
#   29,
#   1,
#   387,
#   2604,
#   80,
#   87,
#   249,
#   53,
#   65,
#   18,
#   3415,
#   19,
#   96,
#   19,
#   295,
#   1,
#   112,
#   51,
#   144,
#   5,
#   765,
#   249,
#   3672,
#   258,
#   23,
#   1,
#   736,
#   68,
#   12,
#   17,
#   47,
#   223,
#   23,
#   7,
#   322,
#   605,
#   1,
#   458,
#   2968,
#   25,
#   782,
#   80,
#   1,
#   258,
#   40,
#   18,
#   126,
#   2,
#   916,
#   10,
#   173,
#   1,
#   176,
#   1390,
#   794,
#   23,
#   7,
#   207,
#   1,
#   296,
#   1307,
#   1,
#   410,
#   31,
#   281,
#   79,
#   79,
#   5,
#   258,
#   103,
#   19,
#   25,
#   47,
#   4,
#   1,
#   61,
#   725,
#   420,
#   31,
#   147,
#   249,
#   725,
#   281,
#   79,
#   63,
#   147,
#   249,
#   725,
#   13,
#   1,
#   481,
#   153,
#   4,
#   249,
#   725,
#   9,
#   7,
#   40,
#   79,
#   23,
#   7,
#   17,
#   701,
#   61,
#   1464,
#   394,
#   1409,
#   9,
#   7,
#   17,
#   2073,
#   87,
#   112,
#   6,
#   857,
#   84,
#   149,
#   7,
#   40,
#   129,
#   5,
#   153,
#   4,
#   1464,
#   7,
#   17,
#   701,
#   30,
#   427,
#   14,
#   158,
#   1208,
#   6,
#   4702,
#   344,
#   83,
#   18,
#   140,
#   47,
#   702,
#   143,
#   44,
#   17,
#   57,
#   857,
#   19,
#   897,
#   15,
#   410,
#   13,
#   270,
#   113,
#   23,
#   1,
#   147,
#   8,
#   1444,
#   173,
#   5,
#   262,
#   176,
#   794,
#   466,
#   281,
#   79,
#   80,
#   1,
#   147,
#   33,
#   18,
#   140,
#   2324,
#   808,
#   143,
#   23,
#   7,
#   17,
#   56,
#   244,
#   51,
#   214,
#   84,
#   31,
#   1,
#   296,
#   249,
#   244,
#   128,
#   7,
#   46,
#   710],
#  [22499, 18, 5, 363, 6, 2141, 530, 10, 335, 139, 1, 2682],
#  [429,
#   37,
#   8,
#   10,
#   46,
#   37,
#   8,
#   10,
#   27,
#   4228,
#   412,
#   4,
#   59,
#   683,
#   47220,
#   60,
#   16,
#   95,
#   31,
#   5519,
#   535,
#   4558,
#   47221,
#   60,
#   3495,
#   71,
#   56,
#   47,
#   60,
#   5172,
#   84,
#   244,
#   20460,
#   87,
#   528,
#   1154,
#   6,
#   5789,
#   262,
#   1308,
#   31,
#   683,
#   214,
#   78107,
#   2,
#   1479,
#   71,
#   66,
#   954,
#   88,
#   251,
#   39,
#   6246,
#   1354],
#  [142,
#   7,
#   404,
#   3938,
#   1418,
#   6,
#   1354,
#   31,
#   39,
#   2141,
#   367,
#   1,
#   77,
#   508,
#   271,
#   1535,
#   4825,
#   582,
#   8,
#   12,
#   155,
#   2,
#   13154,
#   21,
#   581,
#   10,
#   33,
#   1082,
#   92,
#   10,
#   138,
#   49,
#   7,
#   16,
#   2969,
#   21,
#   616,
#   19,
#   27,
#   395,
#   85,
#   1,
#   77,
#   508,
#   8,
#   478,
#   14,
#   8,
#   266,
#   1,
#   494,
#   125,
#   3294,
#   34,
#   1095,
#   8566,
#   42,
#   514,
#   19,
#   4,
#   1293,
#   66,
#   3648,
#   8,
#   320,
#   136,
#   42,
#   8,
#   1,
#   75,
#   791,
#   2949,
#   1195,
#   60,
#   67,
#   12,
#   5160,
#   9,
#   517,
#   58,
#   320,
#   88,
#   66,
#   32566,
#   27,
#   7009,
#   3,
#   2641,
#   2,
#   384,
#   14,
#   77,
#   11,
#   5891,
#   4,
#   15855,
#   1,
#   753,
#   4,
#   27,
#   395,
#   9,
#   8,
#   1263,
#   2,
#   138,
#   31,
#   1,
#   251,
#   508,
#   6,
#   12,
#   2470,
#   1418,
#   303,
#   353,
#   35,
#   15856,
#   354,
#   23,
#   7,
#   3290,
#   5,
#   781,
#   4,
#   2020,
#   117,
#   7,
#   40,
#   20,
#   14,
#   52,
#   40,
#   17,
#   5,
#   3883,
#   130,
#   15,
#   1,
#   424,
#   6,
#   2310,
#   1,
#   338,
#   16066],
#  [396,
#   6,
#   1,
#   1539,
#   238,
#   492,
#   164,
#   965,
#   22,
#   39,
#   163,
#   2584,
#   164,
#   3945,
#   117,
#   10,
#   68,
#   12,
#   1265,
#   3,
#   207,
#   1,
#   581,
#   24,
#   313,
#   39,
#   6,
#   26,
#   49,
#   3,
#   157,
#   1,
#   883,
#   24,
#   3487,
#   6,
#   3,
#   6948,
#   90],
#  [34158,
#   1051,
#   11,
#   2401,
#   34158,
#   19627,
#   24,
#   871,
#   255,
#   324,
#   80,
#   550,
#   1225,
#   5533,
#   55,
#   378,
#   34158,
#   1324,
#   921,
#   271,
#   1742,
#   22,
#   1,
#   23127,
#   1,
#   735,
#   43605,
#   2,
#   18,
#   2100,
#   2,
#   10403,
#   1856,
#   173,
#   6765,
#   5,
#   17194,
#   11,
#   1865,
#   42,
#   24,
#   596,
#   255,
#   324,
#   938,
#   74,
#   22,
#   66,
#   159,
#   3571,
#   19627,
#   1536,
#   6,
#   302,
#   35,
#   275,
#   42,
#   8,
#   851,
#   11,
#   6151,
#   42,
#   118,
#   8,
#   73,
#   93,
#   42,
#   18,
#   2155,
#   80,
#   9036,
#   6247,
#   6,
#   73,
#   93,
#   42,
#   18,
#   898,
#   78,
#   66,
#   3904,
#   2089,
#   1,
#   15596,
#   43605,
#   8,
#   967,
#   255,
#   324,
#   6151,
#   624,
#   34158,
#   649,
#   462,
#   9379,
#   23,
#   21,
#   891,
#   34,
#   9,
#   7515,
#   967,
#   107,
#   2,
#   21,
#   6,
#   161,
#   888,
#   66,
#   388,
#   4,
#   1622,
#   28,
#   462],
#  [2500, 20, 12, 138, 253, 25, 64, 4, 17821, 151, 15180],
#  [415, 46, 1728, 51733, 98417],
#  [1, 114, 124, 48, 442, 76, 12, 1297, 2, 425, 4617, 15, 43606, 2, 425, 58, 99],
#  [20,
#   12,
#   257,
#   2,
#   1573,
#   7,
#   3,
#   63,
#   9,
#   7,
#   16,
#   521,
#   154,
#   431,
#   496,
#   204,
#   629,
#   62,
#   6,
#   23,
#   7,
#   20,
#   396,
#   96,
#   26,
#   23,
#   12,
#   6,
#   7,
#   40,
#   40669,
#   530,
#   14,
#   22,
#   39,
#   80,
#   91,
#   188,
#   3,
#   32,
#   49,
#   2,
#   214,
#   7,
#   2,
#   152,
#   5,
#   2771,
#   138,
#   31,
#   1,
#   7769,
#   3683,
#   3851,
#   25952,
#   6,
#   1,
#   901,
#   420,
#   11,
#   10,
#   1588,
#   105,
#   901,
#   1265,
#   785,
#   11,
#   59,
#   25952,
#   8,
#   36,
#   204,
#   9,
#   7,
#   64,
#   52,
#   40,
#   20,
#   22,
#   1,
#   25952,
#   1495,
#   98418,
#   10]]

# %%
print("Loading the pre-trained word embedding.")
embeddings_index = data_loader.load_embedding('features/crawl-300d-2M.vec')
embedding_matrix = data_transformer.build_embedding_matrix(embeddings_index)
print("Loaded")
# Out:
# Loading the pre-trained word embedding.
# Total 2000000 word vectors.
# Null word embeddings: 22573
# Loaded

# %% [markdown]
# ## Build model

# %%
import importlib
import sotoxic.models.pytorch.bgru as bgru
import sotoxic.train.trainer as trn
importlib.reload(bgru)
importlib.reload(trn)
# Out:
# <module 'sotoxic.train.trainer' from '/home/zake7749/PycharmProjects/CCP/sotoxic/train/trainer.py'>

# %%
def get_bgru_network():
    embedding = nn.Embedding(VOCAB_SIZE, EMBEDDING_SIZE)
    embedding.weight.data.copy_(torch.from_numpy(embedding_matrix))
    embedding.weight.requires_grad=False
    return bgru.BayesianGRUClassifier(input_size=EMBEDDING_SIZE, hidden_size=60, embedding=embedding)

# %% [markdown]
# ## Training

# %%
trainer = trn.PyTorchModelTrainer(model_stamp="FASTTXT_BGRU_64_64", epoch_num=300, learning_rate=1e-3,
                                  verbose_round=40, shuffle_inputs=False, early_stopping_round=10)

# %%
model, best_logloss, best_auc, best_val_pred = trainer.train_folds(X=train_sequences, y=training_labels,
                    fold_count=10, batch_size=256, get_model_func=get_bgru_network, skip_fold=0)
# Out:
# Choose the torch base model.
# Training on fold 0
# Epoch:1 Batch:0 Log-loss0.7120054364204407
# Epoch:1 Batch:40 Log-loss0.1323106735944748
# Epoch:1 Batch:80 Log-loss0.07861244678497314
# Epoch:1 Batch:120 Log-loss0.050647079944610596
# Epoch:1 Batch:160 Log-loss0.04874030873179436
# Epoch:1 Batch:200 Log-loss0.05985138937830925
# Epoch:1 Batch:240 Log-loss0.037754934281110764
# Epoch:1 Batch:280 Log-loss0.050901126116514206
# Epoch:1 Batch:320 Log-loss0.06970404833555222
# Epoch:1 Batch:360 Log-loss0.06141173839569092
# Epoch:1 Batch:400 Log-loss0.04935069754719734
# Epoch:1 Batch:440 Log-loss0.0667911097407341
# Epoch:1 Batch:480 Log-loss0.04504765197634697
# Epoch:1 Batch:520 Log-loss0.055000707507133484
# Epoch:1 Batch:560 Log-loss0.036638546735048294
# Epoch average log loss:0.0793381747856204
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch1, val_loss:0.04555952425826937, best_val_loss:0.04555952425826937, best_auc:0.976878537666061
# Epoch:2 Batch:0 Log-loss0.06867814809083939
# Epoch:2 Batch:40 Log-loss0.03992528095841408
# Epoch:2 Batch:80 Log-loss0.046969298273324966
# Epoch:2 Batch:120 Log-loss0.042035061866045
# Epoch:2 Batch:160 Log-loss0.041205327957868576
# Epoch:2 Batch:200 Log-loss0.049056291580200195
# Epoch:2 Batch:240 Log-loss0.07705309242010117
# Epoch:2 Batch:280 Log-loss0.04704364761710167
# Epoch:2 Batch:320 Log-loss0.0487460158765316
# Epoch:2 Batch:360 Log-loss0.05659325793385506
# Epoch:2 Batch:400 Log-loss0.057180922478437424
# Epoch:2 Batch:440 Log-loss0.056150536984205246
# Epoch:2 Batch:480 Log-loss0.03524068742990494
# Epoch:2 Batch:520 Log-loss0.04137372598052025
# Epoch:2 Batch:560 Log-loss0.05214753374457359
# Epoch average log loss:0.05001075967281524
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch2, val_loss:0.04434937140227999, best_val_loss:0.04434937140227999, best_auc:0.9804736220542257
# Epoch:3 Batch:0 Log-loss0.04830276966094971
# Epoch:3 Batch:40 Log-loss0.04096377268433571
# Epoch:3 Batch:80 Log-loss0.050506722182035446
# Epoch:3 Batch:120 Log-loss0.04582715407013893
# Epoch:3 Batch:160 Log-loss0.03807763382792473
# Epoch:3 Batch:200 Log-loss0.05335954949259758
# Epoch:3 Batch:240 Log-loss0.04983651638031006
# Epoch:3 Batch:280 Log-loss0.04252280667424202
# Epoch:3 Batch:320 Log-loss0.06060698255896568
# Epoch:3 Batch:360 Log-loss0.04445343092083931
# Epoch:3 Batch:400 Log-loss0.0501587875187397
# Epoch:3 Batch:440 Log-loss0.06167474016547203
# Epoch:3 Batch:480 Log-loss0.0546649731695652
# Epoch:3 Batch:520 Log-loss0.03097853623330593
# Epoch:3 Batch:560 Log-loss0.05456440895795822
# Epoch average log loss:0.04741293806250074
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch3, val_loss:0.04215973133101202, best_val_loss:0.04215973133101202, best_auc:0.9831964330014121
# Epoch:4 Batch:0 Log-loss0.044340312480926514
# Epoch:4 Batch:40 Log-loss0.029539242386817932
# Epoch:4 Batch:80 Log-loss0.04329937323927879
# Epoch:4 Batch:120 Log-loss0.052374426275491714
# Epoch:4 Batch:160 Log-loss0.04566134512424469
# Epoch:4 Batch:200 Log-loss0.06970560550689697
# Epoch:4 Batch:240 Log-loss0.057286981493234634
# Epoch:4 Batch:280 Log-loss0.06771456450223923
# Epoch:4 Batch:320 Log-loss0.041504886001348495
# Epoch:4 Batch:360 Log-loss0.05768328905105591
# Epoch:4 Batch:400 Log-loss0.0453309565782547
# Epoch:4 Batch:440 Log-loss0.03599371388554573
# Epoch:4 Batch:480 Log-loss0.048371702432632446
# Epoch:4 Batch:520 Log-loss0.06484667211771011
# Epoch:4 Batch:560 Log-loss0.03898661956191063
# Epoch average log loss:0.04605169754275786
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch4, val_loss:0.04104461211755689, best_val_loss:0.04104461211755689, best_auc:0.9848249535806568
# Epoch:5 Batch:0 Log-loss0.037953298538923264
# Epoch:5 Batch:40 Log-loss0.05954471230506897
# Epoch:5 Batch:80 Log-loss0.03514011576771736
# Epoch:5 Batch:120 Log-loss0.07466626912355423
# Epoch:5 Batch:160 Log-loss0.0445808507502079
# Epoch:5 Batch:200 Log-loss0.05395655706524849
# Epoch:5 Batch:240 Log-loss0.05939869210124016
# Epoch:5 Batch:280 Log-loss0.0463140495121479
# Epoch:5 Batch:320 Log-loss0.039417777210474014
# Epoch:5 Batch:360 Log-loss0.03911064937710762
# Epoch:5 Batch:400 Log-loss0.04967992380261421
# Epoch:5 Batch:440 Log-loss0.04370224103331566
# Epoch:5 Batch:480 Log-loss0.044944316148757935
# Epoch:5 Batch:520 Log-loss0.03316333889961243
# Epoch:5 Batch:560 Log-loss0.03341749310493469
# Epoch average log loss:0.04478505265433341
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch5, val_loss:0.04076002593755801, best_val_loss:0.04076002593755801, best_auc:0.9853210580933728
# Epoch:6 Batch:0 Log-loss0.035939380526542664
# Epoch:6 Batch:40 Log-loss0.055933430790901184
# Epoch:6 Batch:80 Log-loss0.04986649751663208
# Epoch:6 Batch:120 Log-loss0.05274675413966179
# Epoch:6 Batch:160 Log-loss0.07919551432132721
# Epoch:6 Batch:200 Log-loss0.06013499200344086
# Epoch:6 Batch:240 Log-loss0.03523259237408638
# Epoch:6 Batch:280 Log-loss0.03885224089026451
# Epoch:6 Batch:320 Log-loss0.047836143523454666
# Epoch:6 Batch:360 Log-loss0.03278129920363426
# Epoch:6 Batch:400 Log-loss0.04611663892865181
# Epoch:6 Batch:440 Log-loss0.04569028690457344
# Epoch:6 Batch:480 Log-loss0.04447239264845848
# Epoch:6 Batch:520 Log-loss0.04127364605665207
# Epoch:6 Batch:560 Log-loss0.029941245913505554
# Epoch average log loss:0.043567589760225796
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch6, val_loss:0.040026577256412024, best_val_loss:0.040026577256412024, best_auc:0.9863640882951649
# Epoch:7 Batch:0 Log-loss0.03992745652794838
# Epoch:7 Batch:40 Log-loss0.034982237964868546
# Epoch:7 Batch:80 Log-loss0.0431690514087677
# Epoch:7 Batch:120 Log-loss0.030462026596069336
# Epoch:7 Batch:160 Log-loss0.04396167770028114
# Epoch:7 Batch:200 Log-loss0.04974162206053734
# Epoch:7 Batch:240 Log-loss0.05741676315665245
# Epoch:7 Batch:280 Log-loss0.06804589182138443
# Epoch:7 Batch:320 Log-loss0.04352782294154167
# Epoch:7 Batch:360 Log-loss0.047447506338357925
# Epoch:7 Batch:400 Log-loss0.04978137090802193
# Epoch:7 Batch:440 Log-loss0.05918342247605324
# Epoch:7 Batch:480 Log-loss0.03971332311630249
# Epoch:7 Batch:520 Log-loss0.03241755813360214
# Epoch:7 Batch:560 Log-loss0.02896280400454998
# Epoch average log loss:0.04303903625612812
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch7, val_loss:0.039330826899868575, best_val_loss:0.039330826899868575, best_auc:0.9868008643454426
# Epoch:8 Batch:0 Log-loss0.05936514213681221
# Epoch:8 Batch:40 Log-loss0.0302696842700243
# Epoch:8 Batch:80 Log-loss0.04756798967719078
# Epoch:8 Batch:120 Log-loss0.04152555391192436
# Epoch:8 Batch:160 Log-loss0.06145668029785156
# Epoch:8 Batch:200 Log-loss0.051588546484708786
# Epoch:8 Batch:240 Log-loss0.03861844167113304
# Epoch:8 Batch:280 Log-loss0.05779844522476196
# Epoch:8 Batch:320 Log-loss0.032732538878917694
# Epoch:8 Batch:360 Log-loss0.03579225391149521
# Epoch:8 Batch:400 Log-loss0.041509777307510376
# Epoch:8 Batch:440 Log-loss0.04704805091023445
# Epoch:8 Batch:480 Log-loss0.038060083985328674
# Epoch:8 Batch:520 Log-loss0.04304433986544609
# Epoch:8 Batch:560 Log-loss0.05566395819187164
# Epoch average log loss:0.04216378396709582
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch8, val_loss:0.03889493152577631, best_val_loss:0.03889493152577631, best_auc:0.9878324618173928
# Epoch:9 Batch:0 Log-loss0.0571688674390316
# Epoch:9 Batch:40 Log-loss0.04262637719511986
# Epoch:9 Batch:80 Log-loss0.02655140310525894
# Epoch:9 Batch:120 Log-loss0.043560054153203964
# Epoch:9 Batch:160 Log-loss0.05560952052474022
# Epoch:9 Batch:200 Log-loss0.04212874546647072
# Epoch:9 Batch:240 Log-loss0.02979004569351673
# Epoch:9 Batch:280 Log-loss0.03245263919234276
# Epoch:9 Batch:320 Log-loss0.026346318423748016
# Epoch:9 Batch:360 Log-loss0.040751054883003235
# Epoch:9 Batch:400 Log-loss0.02844347059726715
# Epoch:9 Batch:440 Log-loss0.037340354174375534
# Epoch:9 Batch:480 Log-loss0.03828814998269081
# Epoch:9 Batch:520 Log-loss0.05120089650154114
# Epoch:9 Batch:560 Log-loss0.03552517294883728
# Epoch average log loss:0.041780799171621245
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch9, val_loss:0.038531173758827544, best_val_loss:0.038531173758827544, best_auc:0.9882740412030578
# Epoch:10 Batch:0 Log-loss0.03695434331893921
# Epoch:10 Batch:40 Log-loss0.04090544953942299
# Epoch:10 Batch:80 Log-loss0.05570065602660179
# Epoch:10 Batch:120 Log-loss0.03997639939188957
# Epoch:10 Batch:160 Log-loss0.04213264212012291
# Epoch:10 Batch:200 Log-loss0.03962920978665352
# Epoch:10 Batch:240 Log-loss0.040476951748132706
# Epoch:10 Batch:280 Log-loss0.04190034046769142
# Epoch:10 Batch:320 Log-loss0.044796139001846313
# Epoch:10 Batch:360 Log-loss0.03308139368891716
# Epoch:10 Batch:400 Log-loss0.051052410155534744
# Epoch:10 Batch:440 Log-loss0.0357748419046402
# Epoch:10 Batch:480 Log-loss0.032477814704179764
# Epoch:10 Batch:520 Log-loss0.05190897360444069
# Epoch:10 Batch:560 Log-loss0.03744189813733101
# Epoch average log loss:0.04090871061531028
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch10, val_loss:0.03803986401146478, best_val_loss:0.03803986401146478, best_auc:0.9886834264795996
# Epoch:11 Batch:0 Log-loss0.03530322387814522
# Epoch:11 Batch:40 Log-loss0.03929544612765312
# Epoch:11 Batch:80 Log-loss0.04489068314433098
# Epoch:11 Batch:120 Log-loss0.034296635538339615
# Epoch:11 Batch:160 Log-loss0.035722535103559494
# Epoch:11 Batch:200 Log-loss0.04076075181365013
# Epoch:11 Batch:240 Log-loss0.027380459010601044
# Epoch:11 Batch:280 Log-loss0.05594487488269806
# Epoch:11 Batch:320 Log-loss0.04280964657664299
# Epoch:11 Batch:360 Log-loss0.040003590285778046
# Epoch:11 Batch:400 Log-loss0.048115745186805725
# Epoch:11 Batch:440 Log-loss0.028943320736289024
# Epoch:11 Batch:480 Log-loss0.0420382060110569
# Epoch:11 Batch:520 Log-loss0.0317797027528286
# Epoch:11 Batch:560 Log-loss0.052402906119823456
# Epoch average log loss:0.04069471282418817
# In Epoch11, val_loss:0.03819792237609317, best_val_loss:0.03803986401146478, best_auc:0.9886834264795996
# Epoch:12 Batch:0 Log-loss0.0224236398935318
# Epoch:12 Batch:40 Log-loss0.04290938749909401
# Epoch:12 Batch:80 Log-loss0.03902919963002205
# Epoch:12 Batch:120 Log-loss0.04078105464577675
# Epoch:12 Batch:160 Log-loss0.03167366608977318
# Epoch:12 Batch:200 Log-loss0.04649972915649414
# Epoch:12 Batch:240 Log-loss0.049783289432525635
# Epoch:12 Batch:280 Log-loss0.0434969998896122
# Epoch:12 Batch:320 Log-loss0.02270817570388317
# Epoch:12 Batch:360 Log-loss0.041368432343006134
# Epoch:12 Batch:400 Log-loss0.034349750727415085
# Epoch:12 Batch:440 Log-loss0.03214189037680626
# Epoch:12 Batch:480 Log-loss0.026861103251576424
# Epoch:12 Batch:520 Log-loss0.0471443235874176
# Epoch:12 Batch:560 Log-loss0.03870300576090813
# Epoch average log loss:0.040244564058126084
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch12, val_loss:0.03772386062401634, best_val_loss:0.03772386062401634, best_auc:0.9891847812434168
# Epoch:13 Batch:0 Log-loss0.060291845351457596
# Epoch:13 Batch:40 Log-loss0.04330018162727356
# Epoch:13 Batch:80 Log-loss0.044248636811971664
# Epoch:13 Batch:120 Log-loss0.032636284828186035
# Epoch:13 Batch:160 Log-loss0.045553743839263916
# Epoch:13 Batch:200 Log-loss0.02872871421277523
# Epoch:13 Batch:240 Log-loss0.04538087174296379
# Epoch:13 Batch:280 Log-loss0.03926897794008255
# Epoch:13 Batch:320 Log-loss0.045715559273958206
# Epoch:13 Batch:360 Log-loss0.04150130972266197
# Epoch:13 Batch:400 Log-loss0.03738865256309509
# Epoch:13 Batch:440 Log-loss0.03178480267524719
# Epoch:13 Batch:480 Log-loss0.04769943282008171
# Epoch:13 Batch:520 Log-loss0.02698323130607605
# Epoch:13 Batch:560 Log-loss0.040955834090709686
# Epoch average log loss:0.039668001653626564
# In Epoch13, val_loss:0.0377531890928375, best_val_loss:0.03772386062401634, best_auc:0.9891847812434168
# Epoch:14 Batch:0 Log-loss0.03509269654750824
# Epoch:14 Batch:40 Log-loss0.030732452869415283
# Epoch:14 Batch:80 Log-loss0.050405409187078476
# Epoch:14 Batch:120 Log-loss0.045347388833761215
# Epoch:14 Batch:160 Log-loss0.040238894522190094
# Epoch:14 Batch:200 Log-loss0.04657888785004616
# Epoch:14 Batch:240 Log-loss0.04376591369509697
# Epoch:14 Batch:280 Log-loss0.03076501004397869
# Epoch:14 Batch:320 Log-loss0.05770501121878624
# Epoch:14 Batch:360 Log-loss0.0357428602874279
# Epoch:14 Batch:400 Log-loss0.054260771721601486
# Epoch:14 Batch:440 Log-loss0.03408332169055939
# Epoch:14 Batch:480 Log-loss0.04128219559788704
# Epoch:14 Batch:520 Log-loss0.028443820774555206
# Epoch:14 Batch:560 Log-loss0.03651941940188408
# Epoch average log loss:0.039487611149836864
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch14, val_loss:0.03770914891211926, best_val_loss:0.03770914891211926, best_auc:0.9891352863867117
# Epoch:15 Batch:0 Log-loss0.04915967956185341
# Epoch:15 Batch:40 Log-loss0.03083048202097416
# Epoch:15 Batch:80 Log-loss0.037839557975530624
# Epoch:15 Batch:120 Log-loss0.04802577197551727
# Epoch:15 Batch:160 Log-loss0.03994175046682358
# Epoch:15 Batch:200 Log-loss0.0371636338531971
# Epoch:15 Batch:240 Log-loss0.03508050739765167
# Epoch:15 Batch:280 Log-loss0.026659322902560234
# Epoch:15 Batch:320 Log-loss0.03200378641486168
# Epoch:15 Batch:360 Log-loss0.04112040624022484
# Epoch:15 Batch:400 Log-loss0.036452144384384155
# Epoch:15 Batch:440 Log-loss0.04047171398997307
# Epoch:15 Batch:480 Log-loss0.03129281848669052
# Epoch:15 Batch:520 Log-loss0.05017142370343208
# Epoch:15 Batch:560 Log-loss0.036765579134225845
# Epoch average log loss:0.039163759788165664
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch15, val_loss:0.03769336894943021, best_val_loss:0.03769336894943021, best_auc:0.9892264731964048
# Epoch:16 Batch:0 Log-loss0.033707521855831146
# Epoch:16 Batch:40 Log-loss0.04967847466468811
# Epoch:16 Batch:80 Log-loss0.061272840946912766
# Epoch:16 Batch:120 Log-loss0.0377248115837574
# Epoch:16 Batch:160 Log-loss0.033359382301568985
# Epoch:16 Batch:200 Log-loss0.05108053609728813
# Epoch:16 Batch:240 Log-loss0.02579716593027115
# Epoch:16 Batch:280 Log-loss0.034421276301145554
# Epoch:16 Batch:320 Log-loss0.04456759989261627
# Epoch:16 Batch:360 Log-loss0.04775548353791237
# Epoch:16 Batch:400 Log-loss0.04677410423755646
# Epoch:16 Batch:440 Log-loss0.04755590856075287
# Epoch:16 Batch:480 Log-loss0.03218359872698784
# Epoch:16 Batch:520 Log-loss0.04928584396839142
# Epoch:16 Batch:560 Log-loss0.03954445943236351
# Epoch average log loss:0.03911433703864792
# In Epoch16, val_loss:0.03793768018918047, best_val_loss:0.03769336894943021, best_auc:0.9892264731964048
# Epoch:17 Batch:0 Log-loss0.04665709659457207
# Epoch:17 Batch:40 Log-loss0.030883660539984703
# Epoch:17 Batch:80 Log-loss0.029673494398593903
# Epoch:17 Batch:120 Log-loss0.02570403181016445
# Epoch:17 Batch:160 Log-loss0.03809676691889763
# Epoch:17 Batch:200 Log-loss0.03503228351473808
# Epoch:17 Batch:240 Log-loss0.04171283543109894
# Epoch:17 Batch:280 Log-loss0.03663165494799614
# Epoch:17 Batch:320 Log-loss0.05492253601551056
# Epoch:17 Batch:360 Log-loss0.03774653747677803
# Epoch:17 Batch:400 Log-loss0.03281967341899872
# Epoch:17 Batch:440 Log-loss0.04743754491209984
# Epoch:17 Batch:480 Log-loss0.042677734047174454
# Epoch:17 Batch:520 Log-loss0.03689684718847275
# Epoch:17 Batch:560 Log-loss0.03080877847969532
# Epoch average log loss:0.039086649447147334
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch17, val_loss:0.03733626075097543, best_val_loss:0.03733626075097543, best_auc:0.9890794771232595
# Epoch:18 Batch:0 Log-loss0.031091362237930298
# Epoch:18 Batch:40 Log-loss0.04164903983473778
# Epoch:18 Batch:80 Log-loss0.05218102037906647
# Epoch:18 Batch:120 Log-loss0.04123418405652046
# Epoch:18 Batch:160 Log-loss0.028827277943491936
# Epoch:18 Batch:200 Log-loss0.0318727046251297
# Epoch:18 Batch:240 Log-loss0.032309211790561676
# Epoch:18 Batch:280 Log-loss0.045698728412389755
# Epoch:18 Batch:320 Log-loss0.06347060948610306
# Epoch:18 Batch:360 Log-loss0.040234923362731934
# Epoch:18 Batch:400 Log-loss0.043210744857788086
# Epoch:18 Batch:440 Log-loss0.0306980162858963
# Epoch:18 Batch:480 Log-loss0.04811590909957886
# Epoch:18 Batch:520 Log-loss0.028183894231915474
# Epoch:18 Batch:560 Log-loss0.04587263613939285
# Epoch average log loss:0.0387977229331487
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch18, val_loss:0.03724741371682446, best_val_loss:0.03724741371682446, best_auc:0.9893603398944103
# Epoch:19 Batch:0 Log-loss0.040433354675769806
# Epoch:19 Batch:40 Log-loss0.045817479491233826
# Epoch:19 Batch:80 Log-loss0.05360683426260948
# Epoch:19 Batch:120 Log-loss0.05828571319580078
# Epoch:19 Batch:160 Log-loss0.04043808579444885
# Epoch:19 Batch:200 Log-loss0.024384962394833565
# Epoch:19 Batch:240 Log-loss0.04166371375322342
# Epoch:19 Batch:280 Log-loss0.05821231007575989
# Epoch:19 Batch:320 Log-loss0.03888482227921486
# Epoch:19 Batch:360 Log-loss0.04209063574671745
# Epoch:19 Batch:400 Log-loss0.03534097224473953
# Epoch:19 Batch:440 Log-loss0.02912217192351818
# Epoch:19 Batch:480 Log-loss0.03045186959207058
# Epoch:19 Batch:520 Log-loss0.05266507342457771
# Epoch:19 Batch:560 Log-loss0.04180420935153961
# Epoch average log loss:0.03868482537634139
# In Epoch19, val_loss:0.03725522742800543, best_val_loss:0.03724741371682446, best_auc:0.9893603398944103
# Epoch:20 Batch:0 Log-loss0.034415099769830704
# Epoch:20 Batch:40 Log-loss0.03907474875450134
# Epoch:20 Batch:80 Log-loss0.03349713981151581
# Epoch:20 Batch:120 Log-loss0.038461823016405106
# Epoch:20 Batch:160 Log-loss0.038610685616731644
# Epoch:20 Batch:200 Log-loss0.040330883115530014
# Epoch:20 Batch:240 Log-loss0.04207126423716545
# Epoch:20 Batch:280 Log-loss0.03351474553346634
# Epoch:20 Batch:320 Log-loss0.04276834428310394
# Epoch:20 Batch:360 Log-loss0.04138711094856262
# Epoch:20 Batch:400 Log-loss0.02659069560468197
# Epoch:20 Batch:440 Log-loss0.028834976255893707
# Epoch:20 Batch:480 Log-loss0.030315140262246132
# Epoch:20 Batch:520 Log-loss0.034444455057382584
# Epoch:20 Batch:560 Log-loss0.04219679534435272
# Epoch average log loss:0.03847605109414352
# In Epoch20, val_loss:0.03727364605449896, best_val_loss:0.03724741371682446, best_auc:0.9893603398944103
# Epoch:21 Batch:0 Log-loss0.050627946853637695
# Epoch:21 Batch:40 Log-loss0.04329685866832733
# Epoch:21 Batch:80 Log-loss0.027221783995628357
# Epoch:21 Batch:120 Log-loss0.031688518822193146
# Epoch:21 Batch:160 Log-loss0.03505614027380943
# Epoch:21 Batch:200 Log-loss0.03058973141014576
# Epoch:21 Batch:240 Log-loss0.0388977937400341
# Epoch:21 Batch:280 Log-loss0.045375410467386246
# Epoch:21 Batch:320 Log-loss0.03246944025158882
# Epoch:21 Batch:360 Log-loss0.037186432629823685
# Epoch:21 Batch:400 Log-loss0.02860615961253643
# Epoch:21 Batch:440 Log-loss0.044276703149080276
# Epoch:21 Batch:480 Log-loss0.03197610005736351
# Epoch:21 Batch:520 Log-loss0.045383941382169724
# Epoch:21 Batch:560 Log-loss0.034185316413640976
# Epoch average log loss:0.03812314389007432
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch21, val_loss:0.0371718983965491, best_val_loss:0.0371718983965491, best_auc:0.9893133946687094
# Epoch:22 Batch:0 Log-loss0.028315536677837372
# Epoch:22 Batch:40 Log-loss0.027140600606799126
# Epoch:22 Batch:80 Log-loss0.03417358174920082
# Epoch:22 Batch:120 Log-loss0.03949957713484764
# Epoch:22 Batch:160 Log-loss0.040738221257925034
# Epoch:22 Batch:200 Log-loss0.04176154360175133
# Epoch:22 Batch:240 Log-loss0.035430703312158585
# Epoch:22 Batch:280 Log-loss0.03903495892882347
# Epoch:22 Batch:320 Log-loss0.04774244502186775
# Epoch:22 Batch:360 Log-loss0.042632121592760086
# Epoch:22 Batch:400 Log-loss0.031806278973817825
# Epoch:22 Batch:440 Log-loss0.052811335772275925
# Epoch:22 Batch:480 Log-loss0.049546193331480026
# Epoch:22 Batch:520 Log-loss0.030499249696731567
# Epoch:22 Batch:560 Log-loss0.046400729566812515
# Epoch average log loss:0.03817291741059827
# In Epoch22, val_loss:0.03727735940354575, best_val_loss:0.0371718983965491, best_auc:0.9893133946687094
# Epoch:23 Batch:0 Log-loss0.02294871397316456
# Epoch:23 Batch:40 Log-loss0.02319283038377762
# Epoch:23 Batch:80 Log-loss0.0313132219016552
# Epoch:23 Batch:120 Log-loss0.029488638043403625
# Epoch:23 Batch:160 Log-loss0.035033468157052994
# Epoch:23 Batch:200 Log-loss0.039489444345235825
# Epoch:23 Batch:240 Log-loss0.03596692532300949
# Epoch:23 Batch:280 Log-loss0.04450378939509392
# Epoch:23 Batch:320 Log-loss0.03608432412147522
# Epoch:23 Batch:360 Log-loss0.04406682774424553
# Epoch:23 Batch:400 Log-loss0.041250213980674744
# Epoch:23 Batch:440 Log-loss0.04606792330741882
# Epoch:23 Batch:480 Log-loss0.041651662439107895
# Epoch:23 Batch:520 Log-loss0.03261914476752281
# Epoch:23 Batch:560 Log-loss0.036399904638528824
# Epoch average log loss:0.03809540901233309
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch23, val_loss:0.03710159828232489, best_val_loss:0.03710159828232489, best_auc:0.9893839104341803
# Epoch:24 Batch:0 Log-loss0.020188087597489357
# Epoch:24 Batch:40 Log-loss0.029546143487095833
# Epoch:24 Batch:80 Log-loss0.03559206798672676
# Epoch:24 Batch:120 Log-loss0.035080354660749435
# Epoch:24 Batch:160 Log-loss0.04346700385212898
# Epoch:24 Batch:200 Log-loss0.033350542187690735
# Epoch:24 Batch:240 Log-loss0.04141024872660637
# Epoch:24 Batch:280 Log-loss0.036230068653821945
# Epoch:24 Batch:320 Log-loss0.04182161018252373
# Epoch:24 Batch:360 Log-loss0.05584610626101494
# Epoch:24 Batch:400 Log-loss0.04062120243906975
# Epoch:24 Batch:440 Log-loss0.05156521499156952
# Epoch:24 Batch:480 Log-loss0.04834919795393944
# Epoch:24 Batch:520 Log-loss0.03379335626959801
# Epoch:24 Batch:560 Log-loss0.033295001834630966
# Epoch average log loss:0.03789077893431698
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch24, val_loss:0.03702593379868117, best_val_loss:0.03702593379868117, best_auc:0.9892036964695868
# Epoch:25 Batch:0 Log-loss0.026977354660630226
# Epoch:25 Batch:40 Log-loss0.0368429534137249
# Epoch:25 Batch:80 Log-loss0.033793289214372635
# Epoch:25 Batch:120 Log-loss0.049247365444898605
# Epoch:25 Batch:160 Log-loss0.03754157945513725
# Epoch:25 Batch:200 Log-loss0.026966562494635582
# Epoch:25 Batch:240 Log-loss0.03238988667726517
# Epoch:25 Batch:280 Log-loss0.04154418781399727
# Epoch:25 Batch:320 Log-loss0.03437783196568489
# Epoch:25 Batch:360 Log-loss0.03344954177737236
# Epoch:25 Batch:400 Log-loss0.04158373549580574
# Epoch:25 Batch:440 Log-loss0.04108862206339836
# Epoch:25 Batch:480 Log-loss0.02522909641265869
# Epoch:25 Batch:520 Log-loss0.035650383681058884
# Epoch:25 Batch:560 Log-loss0.0408538319170475
# Epoch average log loss:0.037777050524683935
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch25, val_loss:0.03696104645055152, best_val_loss:0.03696104645055152, best_auc:0.9891425178489727
# Epoch:26 Batch:0 Log-loss0.05380634590983391
# Epoch:26 Batch:40 Log-loss0.025991901755332947
# Epoch:26 Batch:80 Log-loss0.032185498625040054
# Epoch:26 Batch:120 Log-loss0.042781099677085876
# Epoch:26 Batch:160 Log-loss0.03918003663420677
# Epoch:26 Batch:200 Log-loss0.037711191922426224
# Epoch:26 Batch:240 Log-loss0.03837515786290169
# Epoch:26 Batch:280 Log-loss0.02656410075724125
# Epoch:26 Batch:320 Log-loss0.04705999419093132
# Epoch:26 Batch:360 Log-loss0.0540807731449604
# Epoch:26 Batch:400 Log-loss0.04832648113369942
# Epoch:26 Batch:440 Log-loss0.027250604704022408
# Epoch:26 Batch:480 Log-loss0.029266655445098877
# Epoch:26 Batch:520 Log-loss0.0542508028447628
# Epoch:26 Batch:560 Log-loss0.03042042814195156
# Epoch average log loss:0.037758879173946165
# In Epoch26, val_loss:0.037000756418785495, best_val_loss:0.03696104645055152, best_auc:0.9891425178489727
# Epoch:27 Batch:0 Log-loss0.03724614158272743
# Epoch:27 Batch:40 Log-loss0.032132554799318314
# Epoch:27 Batch:80 Log-loss0.04139873385429382
# Epoch:27 Batch:120 Log-loss0.03571419045329094
# Epoch:27 Batch:160 Log-loss0.04403592273592949
# Epoch:27 Batch:200 Log-loss0.04969759285449982
# Epoch:27 Batch:240 Log-loss0.0329265296459198
# Epoch:27 Batch:280 Log-loss0.04414353892207146
# Epoch:27 Batch:320 Log-loss0.04011565446853638
# Epoch:27 Batch:360 Log-loss0.036212194710969925
# Epoch:27 Batch:400 Log-loss0.03839101269841194
# Epoch:27 Batch:440 Log-loss0.041472528129816055
# Epoch:27 Batch:480 Log-loss0.03777704015374184
# Epoch:27 Batch:520 Log-loss0.037891123443841934
# Epoch:27 Batch:560 Log-loss0.05033440887928009
# Epoch average log loss:0.03771877424525363
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch27, val_loss:0.036953444690154345, best_val_loss:0.036953444690154345, best_auc:0.9895186046708294
# Epoch:28 Batch:0 Log-loss0.03435344621539116
# Epoch:28 Batch:40 Log-loss0.03544742986559868
# Epoch:28 Batch:80 Log-loss0.027348199859261513
# Epoch:28 Batch:120 Log-loss0.05521097779273987
# Epoch:28 Batch:160 Log-loss0.036024272441864014
# Epoch:28 Batch:200 Log-loss0.031570933759212494
# Epoch:28 Batch:240 Log-loss0.06176721677184105
# Epoch:28 Batch:280 Log-loss0.038737863302230835
# Epoch:28 Batch:320 Log-loss0.04648162052035332
# Epoch:28 Batch:360 Log-loss0.03659859299659729
# Epoch:28 Batch:400 Log-loss0.03391778841614723
# Epoch:28 Batch:440 Log-loss0.03358413279056549
# Epoch:28 Batch:480 Log-loss0.03738055005669594
# Epoch:28 Batch:520 Log-loss0.030275478959083557
# Epoch:28 Batch:560 Log-loss0.031242234632372856
# Epoch average log loss:0.037374141542906206
# In Epoch28, val_loss:0.037056066856172847, best_val_loss:0.036953444690154345, best_auc:0.9895186046708294
# Epoch:29 Batch:0 Log-loss0.0413806326687336
# Epoch:29 Batch:40 Log-loss0.0488111674785614
# Epoch:29 Batch:80 Log-loss0.03226311132311821
# Epoch:29 Batch:120 Log-loss0.060494571924209595
# Epoch:29 Batch:160 Log-loss0.030656667426228523
# Epoch:29 Batch:200 Log-loss0.03970308601856232
# Epoch:29 Batch:240 Log-loss0.03575023636221886
# Epoch:29 Batch:280 Log-loss0.03034629113972187
# Epoch:29 Batch:320 Log-loss0.024671025574207306
# Epoch:29 Batch:360 Log-loss0.024531090632081032
# Epoch:29 Batch:400 Log-loss0.04132862016558647
# Epoch:29 Batch:440 Log-loss0.03334791958332062
# Epoch:29 Batch:480 Log-loss0.02805553376674652
# Epoch:29 Batch:520 Log-loss0.02885289490222931
# Epoch:29 Batch:560 Log-loss0.0316438302397728
# Epoch average log loss:0.03750020012126437
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch29, val_loss:0.036946430352045465, best_val_loss:0.036946430352045465, best_auc:0.9895059606832097
# Epoch:30 Batch:0 Log-loss0.05984675511717796
# Epoch:30 Batch:40 Log-loss0.04036632180213928
# Epoch:30 Batch:80 Log-loss0.034646015614271164
# Epoch:30 Batch:120 Log-loss0.03820523992180824
# Epoch:30 Batch:160 Log-loss0.03649530187249184
# Epoch:30 Batch:200 Log-loss0.04038769379258156
# Epoch:30 Batch:240 Log-loss0.029921114444732666
# Epoch:30 Batch:280 Log-loss0.034326136112213135
# Epoch:30 Batch:320 Log-loss0.028550120070576668
# Epoch:30 Batch:360 Log-loss0.04097624495625496
# Epoch:30 Batch:400 Log-loss0.017992248758673668
# Epoch:30 Batch:440 Log-loss0.03207756578922272
# Epoch:30 Batch:480 Log-loss0.04349773749709129
# Epoch:30 Batch:520 Log-loss0.037456002086400986
# Epoch:30 Batch:560 Log-loss0.033697545528411865
# Epoch average log loss:0.037322685643032726
# In Epoch30, val_loss:0.037249935469444, best_val_loss:0.036946430352045465, best_auc:0.9895059606832097
# Epoch:31 Batch:0 Log-loss0.03137374296784401
# Epoch:31 Batch:40 Log-loss0.03188662603497505
# Epoch:31 Batch:80 Log-loss0.03696281835436821
# Epoch:31 Batch:120 Log-loss0.03559885919094086
# Epoch:31 Batch:160 Log-loss0.050297532230615616
# Epoch:31 Batch:200 Log-loss0.043092016130685806
# Epoch:31 Batch:240 Log-loss0.04278978705406189
# Epoch:31 Batch:280 Log-loss0.03934822231531143
# Epoch:31 Batch:320 Log-loss0.03354959562420845
# Epoch:31 Batch:360 Log-loss0.04686437547206879
# Epoch:31 Batch:400 Log-loss0.024503132328391075
# Epoch:31 Batch:440 Log-loss0.04252990707755089
# Epoch:31 Batch:480 Log-loss0.06017795577645302
# Epoch:31 Batch:520 Log-loss0.03907265514135361
# Epoch:31 Batch:560 Log-loss0.03912781924009323
# Epoch average log loss:0.037238247958677154
# In Epoch31, val_loss:0.03694850825224764, best_val_loss:0.036946430352045465, best_auc:0.9895059606832097
# Epoch:32 Batch:0 Log-loss0.024550022557377815
# Epoch:32 Batch:40 Log-loss0.03845107555389404
# Epoch:32 Batch:80 Log-loss0.02943115495145321
# Epoch:32 Batch:120 Log-loss0.030277058482170105
# Epoch:32 Batch:160 Log-loss0.03996164724230766
# Epoch:32 Batch:200 Log-loss0.039609313011169434
# Epoch:32 Batch:240 Log-loss0.04094173386693001
# Epoch:32 Batch:280 Log-loss0.024875901639461517
# Epoch:32 Batch:320 Log-loss0.04521198570728302
# Epoch:32 Batch:360 Log-loss0.04523533210158348
# Epoch:32 Batch:400 Log-loss0.03908118978142738
# Epoch:32 Batch:440 Log-loss0.036674533039331436
# Epoch:32 Batch:480 Log-loss0.04959762468934059
# Epoch:32 Batch:520 Log-loss0.03626297786831856
# Epoch:32 Batch:560 Log-loss0.0260720644146204
# Epoch average log loss:0.037177649117074905
# In Epoch32, val_loss:0.036954077171879686, best_val_loss:0.036946430352045465, best_auc:0.9895059606832097
# Epoch:33 Batch:0 Log-loss0.045042458921670914
# Epoch:33 Batch:40 Log-loss0.037948690354824066
# Epoch:33 Batch:80 Log-loss0.031077692285180092
# Epoch:33 Batch:120 Log-loss0.02989860810339451
# Epoch:33 Batch:160 Log-loss0.024002818390727043
# Epoch:33 Batch:200 Log-loss0.024053893983364105
# Epoch:33 Batch:240 Log-loss0.035787809640169144
# Epoch:33 Batch:280 Log-loss0.03394898772239685
# Epoch:33 Batch:320 Log-loss0.026800906285643578
# Epoch:33 Batch:360 Log-loss0.03313779458403587
# Epoch:33 Batch:400 Log-loss0.02219502627849579
# Epoch:33 Batch:440 Log-loss0.050508931279182434
# Epoch:33 Batch:480 Log-loss0.037076812237501144
# Epoch:33 Batch:520 Log-loss0.024640297517180443
# Epoch:33 Batch:560 Log-loss0.03511400893330574
# Epoch average log loss:0.03723317169185195
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch33, val_loss:0.03685045472166809, best_val_loss:0.03685045472166809, best_auc:0.9894506123515687
# Epoch:34 Batch:0 Log-loss0.03990698978304863
# Epoch:34 Batch:40 Log-loss0.02200227789580822
# Epoch:34 Batch:80 Log-loss0.03762834146618843
# Epoch:34 Batch:120 Log-loss0.026852922514081
# Epoch:34 Batch:160 Log-loss0.03547540307044983
# Epoch:34 Batch:200 Log-loss0.03262751176953316
# Epoch:34 Batch:240 Log-loss0.037400633096694946
# Epoch:34 Batch:280 Log-loss0.025090934708714485
# Epoch:34 Batch:320 Log-loss0.03161204233765602
# Epoch:34 Batch:360 Log-loss0.043744370341300964
# Epoch:34 Batch:400 Log-loss0.0383477509021759
# Epoch:34 Batch:440 Log-loss0.02681908756494522
# Epoch:34 Batch:480 Log-loss0.031787145882844925
# Epoch:34 Batch:520 Log-loss0.03384857252240181
# Epoch:34 Batch:560 Log-loss0.04718747362494469
# Epoch average log loss:0.03707045710179955
# In Epoch34, val_loss:0.036882586302734215, best_val_loss:0.03685045472166809, best_auc:0.9894506123515687
# Epoch:35 Batch:0 Log-loss0.05462096258997917
# Epoch:35 Batch:40 Log-loss0.0463414341211319
# Epoch:35 Batch:80 Log-loss0.03695293515920639
# Epoch:35 Batch:120 Log-loss0.03324008360505104
# Epoch:35 Batch:160 Log-loss0.0368196964263916
# Epoch:35 Batch:200 Log-loss0.03477618470788002
# Epoch:35 Batch:240 Log-loss0.03512202575802803
# Epoch:35 Batch:280 Log-loss0.03568184748291969
# Epoch:35 Batch:320 Log-loss0.039729125797748566
# Epoch:35 Batch:360 Log-loss0.030913082882761955
# Epoch:35 Batch:400 Log-loss0.035580527037382126
# Epoch:35 Batch:440 Log-loss0.03301239758729935
# Epoch:35 Batch:480 Log-loss0.06218094751238823
# Epoch:35 Batch:520 Log-loss0.04542786255478859
# Epoch:35 Batch:560 Log-loss0.03753327578306198
# Epoch average log loss:0.03713505689187774
# In Epoch35, val_loss:0.03702416903427235, best_val_loss:0.03685045472166809, best_auc:0.9894506123515687
# Epoch:36 Batch:0 Log-loss0.04245641455054283
# Epoch:36 Batch:40 Log-loss0.04110080003738403
# Epoch:36 Batch:80 Log-loss0.028409035876393318
# Epoch:36 Batch:120 Log-loss0.0379188247025013
# Epoch:36 Batch:160 Log-loss0.04331878200173378
# Epoch:36 Batch:200 Log-loss0.04239397868514061
# Epoch:36 Batch:240 Log-loss0.03958999738097191
# Epoch:36 Batch:280 Log-loss0.03897681459784508
# Epoch:36 Batch:320 Log-loss0.03237045183777809
# Epoch:36 Batch:360 Log-loss0.03319082036614418
# Epoch:36 Batch:400 Log-loss0.029043259099125862
# Epoch:36 Batch:440 Log-loss0.034833163022994995
# Epoch:36 Batch:480 Log-loss0.03226916864514351
# Epoch:36 Batch:520 Log-loss0.03404688090085983
# Epoch:36 Batch:560 Log-loss0.03502083197236061
# Epoch average log loss:0.03716790107178635
# In Epoch36, val_loss:0.03700696661175414, best_val_loss:0.03685045472166809, best_auc:0.9894506123515687
# Epoch:37 Batch:0 Log-loss0.04181408882141113
# Epoch:37 Batch:40 Log-loss0.03812292963266373
# Epoch:37 Batch:80 Log-loss0.027309710159897804
# Epoch:37 Batch:120 Log-loss0.0445278026163578
# Epoch:37 Batch:160 Log-loss0.024697592481970787
# Epoch:37 Batch:200 Log-loss0.042861517518758774
# Epoch:37 Batch:240 Log-loss0.028210438787937164
# Epoch:37 Batch:280 Log-loss0.03396926447749138
# Epoch:37 Batch:320 Log-loss0.03776480257511139
# Epoch:37 Batch:360 Log-loss0.03636036440730095
# Epoch:37 Batch:400 Log-loss0.03484584763646126
# Epoch:37 Batch:440 Log-loss0.04358665272593498
# Epoch:37 Batch:480 Log-loss0.039557263255119324
# Epoch:37 Batch:520 Log-loss0.0317780040204525
# Epoch:37 Batch:560 Log-loss0.036394987255334854
# Epoch average log loss:0.03683391263974564
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch37, val_loss:0.036779424331287926, best_val_loss:0.036779424331287926, best_auc:0.9895815556650747
# Epoch:38 Batch:0 Log-loss0.040687840431928635
# Epoch:38 Batch:40 Log-loss0.04156241938471794
# Epoch:38 Batch:80 Log-loss0.040576811879873276
# Epoch:38 Batch:120 Log-loss0.031041691079735756
# Epoch:38 Batch:160 Log-loss0.04214386269450188
# Epoch:38 Batch:200 Log-loss0.045967068523168564
# Epoch:38 Batch:240 Log-loss0.031998272985219955
# Epoch:38 Batch:280 Log-loss0.03450891748070717
# Epoch:38 Batch:320 Log-loss0.03579799458384514
# Epoch:38 Batch:360 Log-loss0.048357706516981125
# Epoch:38 Batch:400 Log-loss0.03253639116883278
# Epoch:38 Batch:440 Log-loss0.035472165793180466
# Epoch:38 Batch:480 Log-loss0.022564785555005074
# Epoch:38 Batch:520 Log-loss0.026673145592212677
# Epoch:38 Batch:560 Log-loss0.0351593941450119
# Epoch average log loss:0.03698263983907444
# In Epoch38, val_loss:0.03690475596633406, best_val_loss:0.036779424331287926, best_auc:0.9895815556650747
# Epoch:39 Batch:0 Log-loss0.03807559981942177
# Epoch:39 Batch:40 Log-loss0.05057978630065918
# Epoch:39 Batch:80 Log-loss0.045773785561323166
# Epoch:39 Batch:120 Log-loss0.04727158322930336
# Epoch:39 Batch:160 Log-loss0.03808673098683357
# Epoch:39 Batch:200 Log-loss0.025789594277739525
# Epoch:39 Batch:240 Log-loss0.037169378250837326
# Epoch:39 Batch:280 Log-loss0.035156041383743286
# Epoch:39 Batch:320 Log-loss0.05295984074473381
# Epoch:39 Batch:360 Log-loss0.038340236991643906
# Epoch:39 Batch:400 Log-loss0.042638540267944336
# Epoch:39 Batch:440 Log-loss0.027680404484272003
# Epoch:39 Batch:480 Log-loss0.04154578596353531
# Epoch:39 Batch:520 Log-loss0.03126930817961693
# Epoch:39 Batch:560 Log-loss0.04197578877210617
# Epoch average log loss:0.036955274644839976
# In Epoch39, val_loss:0.036881704161292855, best_val_loss:0.036779424331287926, best_auc:0.9895815556650747
# Epoch:40 Batch:0 Log-loss0.03653962165117264
# Epoch:40 Batch:40 Log-loss0.035733941942453384
# Epoch:40 Batch:80 Log-loss0.04277871176600456
# Epoch:40 Batch:120 Log-loss0.046780142933130264
# Epoch:40 Batch:160 Log-loss0.034213826060295105
# Epoch:40 Batch:200 Log-loss0.029059937223792076
# Epoch:40 Batch:240 Log-loss0.031225822865962982
# Epoch:40 Batch:280 Log-loss0.024687020108103752
# Epoch:40 Batch:320 Log-loss0.02799355424940586
# Epoch:40 Batch:360 Log-loss0.03158964961767197
# Epoch:40 Batch:400 Log-loss0.0544680655002594
# Epoch:40 Batch:440 Log-loss0.04156803712248802
# Epoch:40 Batch:480 Log-loss0.036043547093868256
# Epoch:40 Batch:520 Log-loss0.05093027278780937
# Epoch:40 Batch:560 Log-loss0.034555140882730484
# Epoch average log loss:0.036789428060209114
# In Epoch40, val_loss:0.03682717914139827, best_val_loss:0.036779424331287926, best_auc:0.9895815556650747
# Epoch:41 Batch:0 Log-loss0.02822846733033657
# Epoch:41 Batch:40 Log-loss0.032350655645132065
# Epoch:41 Batch:80 Log-loss0.02900460921227932
# Epoch:41 Batch:120 Log-loss0.01946212537586689
# Epoch:41 Batch:160 Log-loss0.025386126711964607
# Epoch:41 Batch:200 Log-loss0.029901819303631783
# Epoch:41 Batch:240 Log-loss0.036139145493507385
# Epoch:41 Batch:280 Log-loss0.04835100844502449
# Epoch:41 Batch:320 Log-loss0.029775559902191162
# Epoch:41 Batch:360 Log-loss0.04188448563218117
# Epoch:41 Batch:400 Log-loss0.03215942904353142
# Epoch:41 Batch:440 Log-loss0.04994639754295349
# Epoch:41 Batch:480 Log-loss0.027630405500531197
# Epoch:41 Batch:520 Log-loss0.031207725405693054
# Epoch:41 Batch:560 Log-loss0.06173643842339516
# Epoch average log loss:0.03692918002073254
# In Epoch41, val_loss:0.03685726816704996, best_val_loss:0.036779424331287926, best_auc:0.9895815556650747
# Epoch:42 Batch:0 Log-loss0.029008449986577034
# Epoch:42 Batch:40 Log-loss0.03451765701174736
# Epoch:42 Batch:80 Log-loss0.03319038823246956
# Epoch:42 Batch:120 Log-loss0.0538812130689621
# Epoch:42 Batch:160 Log-loss0.06701799482107162
# Epoch:42 Batch:200 Log-loss0.03753529489040375
# Epoch:42 Batch:240 Log-loss0.026587555184960365
# Epoch:42 Batch:280 Log-loss0.034241486340761185
# Epoch:42 Batch:320 Log-loss0.037418536841869354
# Epoch:42 Batch:360 Log-loss0.03486824408173561
# Epoch:42 Batch:400 Log-loss0.031203120946884155
# Epoch:42 Batch:440 Log-loss0.03365864232182503
# Epoch:42 Batch:480 Log-loss0.038846664130687714
# Epoch:42 Batch:520 Log-loss0.03252311795949936
# Epoch:42 Batch:560 Log-loss0.04471322149038315
# Epoch average log loss:0.03698213135357946
# In Epoch42, val_loss:0.03689074588253406, best_val_loss:0.036779424331287926, best_auc:0.9895815556650747
# Epoch:43 Batch:0 Log-loss0.04382934048771858
# Epoch:43 Batch:40 Log-loss0.044601913541555405
# Epoch:43 Batch:80 Log-loss0.038064148277044296
# Epoch:43 Batch:120 Log-loss0.030738862231373787
# Epoch:43 Batch:160 Log-loss0.03664319962263107
# Epoch:43 Batch:200 Log-loss0.03386829420924187
# Epoch:43 Batch:240 Log-loss0.05448826774954796
# Epoch:43 Batch:280 Log-loss0.03649897500872612
# Epoch:43 Batch:320 Log-loss0.0428546667098999
# Epoch:43 Batch:360 Log-loss0.035165127366781235
# Epoch:43 Batch:400 Log-loss0.036113426089286804
# Epoch:43 Batch:440 Log-loss0.032082267105579376
# Epoch:43 Batch:480 Log-loss0.04871675372123718
# Epoch:43 Batch:520 Log-loss0.03376783803105354
# Epoch:43 Batch:560 Log-loss0.03364066034555435
# Epoch average log loss:0.03693489140631365
# In Epoch43, val_loss:0.03684379164203771, best_val_loss:0.036779424331287926, best_auc:0.9895815556650747
# Epoch:44 Batch:0 Log-loss0.0368502251803875
# Epoch:44 Batch:40 Log-loss0.04976074397563934
# Epoch:44 Batch:80 Log-loss0.05330665409564972
# Epoch:44 Batch:120 Log-loss0.03899279981851578
# Epoch:44 Batch:160 Log-loss0.052394405007362366
# Epoch:44 Batch:200 Log-loss0.05981970950961113
# Epoch:44 Batch:240 Log-loss0.03944256156682968
# Epoch:44 Batch:280 Log-loss0.04858657345175743
# Epoch:44 Batch:320 Log-loss0.03754880651831627
# Epoch:44 Batch:360 Log-loss0.033855073153972626
# Epoch:44 Batch:400 Log-loss0.0374278761446476
# Epoch:44 Batch:440 Log-loss0.03404397889971733
# Epoch:44 Batch:480 Log-loss0.03144681826233864
# Epoch:44 Batch:520 Log-loss0.038486067205667496
# Epoch:44 Batch:560 Log-loss0.04075628146529198
# Epoch average log loss:0.03681212373942669
# In Epoch44, val_loss:0.03684656920218106, best_val_loss:0.036779424331287926, best_auc:0.9895815556650747
# Epoch:45 Batch:0 Log-loss0.037298642098903656
# Epoch:45 Batch:40 Log-loss0.028539815917611122
# Epoch:45 Batch:80 Log-loss0.03445662930607796
# Epoch:45 Batch:120 Log-loss0.036051880568265915
# Epoch:45 Batch:160 Log-loss0.04764030873775482
# Epoch:45 Batch:200 Log-loss0.0414140410721302
# Epoch:45 Batch:240 Log-loss0.03733081743121147
# Epoch:45 Batch:280 Log-loss0.032368578016757965
# Epoch:45 Batch:320 Log-loss0.055764731019735336
# Epoch:45 Batch:360 Log-loss0.024579323828220367
# Epoch:45 Batch:400 Log-loss0.035887960344552994
# Epoch:45 Batch:440 Log-loss0.020738080143928528
# Epoch:45 Batch:480 Log-loss0.03682814911007881
# Epoch:45 Batch:520 Log-loss0.04296993091702461
# Epoch:45 Batch:560 Log-loss0.04260142147541046
# Epoch average log loss:0.0365080184935193
# In Epoch45, val_loss:0.036841663170472806, best_val_loss:0.036779424331287926, best_auc:0.9895815556650747
# Epoch:46 Batch:0 Log-loss0.0407344214618206
# Epoch:46 Batch:40 Log-loss0.022203238680958748
# Epoch:46 Batch:80 Log-loss0.03187166899442673
# Epoch:46 Batch:120 Log-loss0.031087161973118782
# Epoch:46 Batch:160 Log-loss0.038957629352808
# Epoch:46 Batch:200 Log-loss0.02837744913995266
# Epoch:46 Batch:240 Log-loss0.06378493458032608
# Epoch:46 Batch:280 Log-loss0.038088176399469376
# Epoch:46 Batch:320 Log-loss0.03619389981031418
# Epoch:46 Batch:360 Log-loss0.02844088524580002
# Epoch:46 Batch:400 Log-loss0.02758813463151455
# Epoch:46 Batch:440 Log-loss0.02589370310306549
# Epoch:46 Batch:480 Log-loss0.030248790979385376
# Epoch:46 Batch:520 Log-loss0.03618088364601135
# Epoch:46 Batch:560 Log-loss0.0379677377641201
# Epoch average log loss:0.03664473699006651
# In Epoch46, val_loss:0.036842450227374604, best_val_loss:0.036779424331287926, best_auc:0.9895815556650747
# Epoch:47 Batch:0 Log-loss0.05392705276608467
# Epoch:47 Batch:40 Log-loss0.04010666906833649
# Epoch:47 Batch:80 Log-loss0.03924063220620155
# Epoch:47 Batch:120 Log-loss0.031908068805933
# Epoch:47 Batch:160 Log-loss0.04869798943400383
# Epoch:47 Batch:200 Log-loss0.03346498683094978
# Epoch:47 Batch:240 Log-loss0.03800887614488602
# Epoch:47 Batch:280 Log-loss0.043155938386917114
# Epoch:47 Batch:320 Log-loss0.03454754129052162
# Epoch:47 Batch:360 Log-loss0.0354398675262928
# Epoch:47 Batch:400 Log-loss0.035380031913518906
# Epoch:47 Batch:440 Log-loss0.044184986501932144
# Epoch:47 Batch:480 Log-loss0.03441204875707626
# Epoch:47 Batch:520 Log-loss0.04677858576178551
# Epoch:47 Batch:560 Log-loss0.03860176354646683
# Epoch average log loss:0.03657726087341351
# A pre-trained model at temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt has been loaded.
#
# Model has been saved as checkpoints/FASTTXT_BGRU_64_640.pt.
#
# Choose the torch base model.
# Training on fold 1
# Epoch:1 Batch:0 Log-loss0.6727760434150696
# Epoch:1 Batch:40 Log-loss0.1336449235677719
# Epoch:1 Batch:80 Log-loss0.10393470525741577
# Epoch:1 Batch:120 Log-loss0.057671431452035904
# Epoch:1 Batch:160 Log-loss0.06155194714665413
# Epoch:1 Batch:200 Log-loss0.05471082404255867
# Epoch:1 Batch:240 Log-loss0.057089079171419144
# Epoch:1 Batch:280 Log-loss0.06460430473089218
# Epoch:1 Batch:320 Log-loss0.06532611697912216
# Epoch:1 Batch:360 Log-loss0.04995075985789299
# Epoch:1 Batch:400 Log-loss0.04205774888396263
# Epoch:1 Batch:440 Log-loss0.05861636996269226
# Epoch:1 Batch:480 Log-loss0.06474127620458603
# Epoch:1 Batch:520 Log-loss0.028494814410805702
# Epoch:1 Batch:560 Log-loss0.04608842730522156
# Epoch average log loss:0.08103964133520744
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch1, val_loss:0.04809863237672146, best_val_loss:0.04809863237672146, best_auc:0.9746432936476846
# Epoch:2 Batch:0 Log-loss0.059111401438713074
# Epoch:2 Batch:40 Log-loss0.0558774508535862
# Epoch:2 Batch:80 Log-loss0.054683148860931396
# Epoch:2 Batch:120 Log-loss0.06346443295478821
# Epoch:2 Batch:160 Log-loss0.06967416405677795
# Epoch:2 Batch:200 Log-loss0.037251055240631104
# Epoch:2 Batch:240 Log-loss0.02678484283387661
# Epoch:2 Batch:280 Log-loss0.04401285946369171
# Epoch:2 Batch:320 Log-loss0.0503217913210392
# Epoch:2 Batch:360 Log-loss0.04743117466568947
# Epoch:2 Batch:400 Log-loss0.03669824078679085
# Epoch:2 Batch:440 Log-loss0.05245361104607582
# Epoch:2 Batch:480 Log-loss0.05507412180304527
# Epoch:2 Batch:520 Log-loss0.04662197828292847
# Epoch:2 Batch:560 Log-loss0.05268581584095955
# Epoch average log loss:0.049748783694979336
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch2, val_loss:0.04534472269602024, best_val_loss:0.04534472269602024, best_auc:0.979075226274511
# Epoch:3 Batch:0 Log-loss0.04036319628357887
# Epoch:3 Batch:40 Log-loss0.04105386883020401
# Epoch:3 Batch:80 Log-loss0.04229682683944702
# Epoch:3 Batch:120 Log-loss0.04708269238471985
# Epoch:3 Batch:160 Log-loss0.0401812382042408
# Epoch:3 Batch:200 Log-loss0.03317039832472801
# Epoch:3 Batch:240 Log-loss0.05819818377494812
# Epoch:3 Batch:280 Log-loss0.045551881194114685
# Epoch:3 Batch:320 Log-loss0.034480880945920944
# Epoch:3 Batch:360 Log-loss0.042917266488075256
# Epoch:3 Batch:400 Log-loss0.04687904939055443
# Epoch:3 Batch:440 Log-loss0.036569371819496155
# Epoch:3 Batch:480 Log-loss0.039296746253967285
# Epoch:3 Batch:520 Log-loss0.052068423479795456
# Epoch:3 Batch:560 Log-loss0.05208706110715866
# Epoch average log loss:0.04730017806869
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch3, val_loss:0.04439769968135957, best_val_loss:0.04439769968135957, best_auc:0.98206761775662
# Epoch:4 Batch:0 Log-loss0.04856358841061592
# Epoch:4 Batch:40 Log-loss0.03585114702582359
# Epoch:4 Batch:80 Log-loss0.04838089644908905
# Epoch:4 Batch:120 Log-loss0.03710492327809334
# Epoch:4 Batch:160 Log-loss0.05734674260020256
# Epoch:4 Batch:200 Log-loss0.04462427273392677
# Epoch:4 Batch:240 Log-loss0.03820354864001274
# Epoch:4 Batch:280 Log-loss0.050293225795030594
# Epoch:4 Batch:320 Log-loss0.052235040813684464
# Epoch:4 Batch:360 Log-loss0.064984031021595
# Epoch:4 Batch:400 Log-loss0.029629310593008995
# Epoch:4 Batch:440 Log-loss0.039353467524051666
# Epoch:4 Batch:480 Log-loss0.0680144801735878
# Epoch:4 Batch:520 Log-loss0.057949602603912354
# Epoch:4 Batch:560 Log-loss0.031205227598547935
# Epoch average log loss:0.04585059221634375
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch4, val_loss:0.04299766561462292, best_val_loss:0.04299766561462292, best_auc:0.9841325864710758
# Epoch:5 Batch:0 Log-loss0.056753844022750854
# Epoch:5 Batch:40 Log-loss0.032236773520708084
# Epoch:5 Batch:80 Log-loss0.054152365773916245
# Epoch:5 Batch:120 Log-loss0.04483119025826454
# Epoch:5 Batch:160 Log-loss0.04339274764060974
# Epoch:5 Batch:200 Log-loss0.03879684954881668
# Epoch:5 Batch:240 Log-loss0.04107380658388138
# Epoch:5 Batch:280 Log-loss0.04653553664684296
# Epoch:5 Batch:320 Log-loss0.05834229290485382
# Epoch:5 Batch:360 Log-loss0.060627054423093796
# Epoch:5 Batch:400 Log-loss0.052543770521879196
# Epoch:5 Batch:440 Log-loss0.053448159247636795
# Epoch:5 Batch:480 Log-loss0.047275345772504807
# Epoch:5 Batch:520 Log-loss0.046732138842344284
# Epoch:5 Batch:560 Log-loss0.0499957874417305
# Epoch average log loss:0.04426202046951013
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch5, val_loss:0.04278488127899116, best_val_loss:0.04278488127899116, best_auc:0.9861511124736082
# Epoch:6 Batch:0 Log-loss0.032748375087976456
# Epoch:6 Batch:40 Log-loss0.05271555855870247
# Epoch:6 Batch:80 Log-loss0.052354250103235245
# Epoch:6 Batch:120 Log-loss0.05151710286736488
# Epoch:6 Batch:160 Log-loss0.03506479039788246
# Epoch:6 Batch:200 Log-loss0.044160258024930954
# Epoch:6 Batch:240 Log-loss0.06004012003540993
# Epoch:6 Batch:280 Log-loss0.0337318517267704
# Epoch:6 Batch:320 Log-loss0.027385303750634193
# Epoch:6 Batch:360 Log-loss0.0373309850692749
# Epoch:6 Batch:400 Log-loss0.04664253816008568
# Epoch:6 Batch:440 Log-loss0.05172867700457573
# Epoch:6 Batch:480 Log-loss0.05077628418803215
# Epoch:6 Batch:520 Log-loss0.030392156913876534
# Epoch:6 Batch:560 Log-loss0.040296949446201324
# Epoch average log loss:0.043428950597132955
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch6, val_loss:0.04187963891261338, best_val_loss:0.04187963891261338, best_auc:0.9875733376591457
# Epoch:7 Batch:0 Log-loss0.04411400482058525
# Epoch:7 Batch:40 Log-loss0.028560696169734
# Epoch:7 Batch:80 Log-loss0.02843683399260044
# Epoch:7 Batch:120 Log-loss0.03893585130572319
# Epoch:7 Batch:160 Log-loss0.04648426175117493
# Epoch:7 Batch:200 Log-loss0.04563752934336662
# Epoch:7 Batch:240 Log-loss0.04917936027050018
# Epoch:7 Batch:280 Log-loss0.0383734367787838
# Epoch:7 Batch:320 Log-loss0.03244008496403694
# Epoch:7 Batch:360 Log-loss0.04008994996547699
# Epoch:7 Batch:400 Log-loss0.058085694909095764
# Epoch:7 Batch:440 Log-loss0.04336382821202278
# Epoch:7 Batch:480 Log-loss0.0375632680952549
# Epoch:7 Batch:520 Log-loss0.04676268622279167
# Epoch:7 Batch:560 Log-loss0.05872436240315437
# ...
# Epoch:29 Batch:280 Log-loss0.031594518572092056
# Epoch:29 Batch:320 Log-loss0.025183824822306633
# Epoch:29 Batch:360 Log-loss0.029537402093410492
# Epoch:29 Batch:400 Log-loss0.057713333517313004
# Epoch:29 Batch:440 Log-loss0.03755534812808037
# Epoch:29 Batch:480 Log-loss0.05049026384949684
# Epoch:29 Batch:520 Log-loss0.0325910821557045
# Epoch:29 Batch:560 Log-loss0.0447113960981369
# Epoch average log loss:0.037373624928295615
# In Epoch29, val_loss:0.03734068636775508, best_val_loss:0.03733482266701688, best_auc:0.9891807204146933
# Epoch:30 Batch:0 Log-loss0.03937250003218651
# Epoch:30 Batch:40 Log-loss0.029161972925066948
# Epoch:30 Batch:80 Log-loss0.03263365849852562
# Epoch:30 Batch:120 Log-loss0.03029371239244938
# Epoch:30 Batch:160 Log-loss0.026867644861340523
# Epoch:30 Batch:200 Log-loss0.041316669434309006
# Epoch:30 Batch:240 Log-loss0.043451834470033646
# Epoch:30 Batch:280 Log-loss0.046559423208236694
# Epoch:30 Batch:320 Log-loss0.028353847563266754
# Epoch:30 Batch:360 Log-loss0.026548631489276886
# Epoch:30 Batch:400 Log-loss0.028754549100995064
# Epoch:30 Batch:440 Log-loss0.03933136165142059
# Epoch:30 Batch:480 Log-loss0.0318344384431839
# Epoch:30 Batch:520 Log-loss0.027782054618000984
# Epoch:30 Batch:560 Log-loss0.03751451149582863
# Epoch average log loss:0.03741872648242861
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch30, val_loss:0.03732899875139137, best_val_loss:0.03732899875139137, best_auc:0.9890425745442356
# Epoch:31 Batch:0 Log-loss0.04051419720053673
# Epoch:31 Batch:40 Log-loss0.039691898971796036
# Epoch:31 Batch:80 Log-loss0.0346277616918087
# Epoch:31 Batch:120 Log-loss0.03591184318065643
# Epoch:31 Batch:160 Log-loss0.04546809569001198
# Epoch:31 Batch:200 Log-loss0.041774775832891464
# Epoch:31 Batch:240 Log-loss0.03111187554895878
# Epoch:31 Batch:280 Log-loss0.03959900513291359
# Epoch:31 Batch:320 Log-loss0.026567762717604637
# Epoch:31 Batch:360 Log-loss0.032844822853803635
# Epoch:31 Batch:400 Log-loss0.04191766306757927
# Epoch:31 Batch:440 Log-loss0.039985429495573044
# Epoch:31 Batch:480 Log-loss0.030769670382142067
# Epoch:31 Batch:520 Log-loss0.026361554861068726
# Epoch:31 Batch:560 Log-loss0.04033121466636658
# Epoch average log loss:0.037188925657288305
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch31, val_loss:0.037280518824741884, best_val_loss:0.037280518824741884, best_auc:0.9891612523457282
# Epoch:32 Batch:0 Log-loss0.02555924467742443
# Epoch:32 Batch:40 Log-loss0.043173015117645264
# Epoch:32 Batch:80 Log-loss0.03214317187666893
# Epoch:32 Batch:120 Log-loss0.04182949289679527
# Epoch:32 Batch:160 Log-loss0.048973049968481064
# Epoch:32 Batch:200 Log-loss0.027037186548113823
# Epoch:32 Batch:240 Log-loss0.03429853543639183
# Epoch:32 Batch:280 Log-loss0.04188264533877373
# Epoch:32 Batch:320 Log-loss0.027212508022785187
# Epoch:32 Batch:360 Log-loss0.05423672869801521
# Epoch:32 Batch:400 Log-loss0.026018239557743073
# Epoch:32 Batch:440 Log-loss0.03591928258538246
# Epoch:32 Batch:480 Log-loss0.029280902817845345
# Epoch:32 Batch:520 Log-loss0.03492751345038414
# Epoch:32 Batch:560 Log-loss0.04193948954343796
# Epoch average log loss:0.03728586017553295
# In Epoch32, val_loss:0.03737022754721287, best_val_loss:0.037280518824741884, best_auc:0.9891612523457282
# Epoch:33 Batch:0 Log-loss0.054315660148859024
# Epoch:33 Batch:40 Log-loss0.04033203795552254
# Epoch:33 Batch:80 Log-loss0.030183130875229836
# Epoch:33 Batch:120 Log-loss0.0322297029197216
# Epoch:33 Batch:160 Log-loss0.043465498834848404
# Epoch:33 Batch:200 Log-loss0.043879445642232895
# Epoch:33 Batch:240 Log-loss0.042952507734298706
# Epoch:33 Batch:280 Log-loss0.034070711582899094
# Epoch:33 Batch:320 Log-loss0.0443364717066288
# Epoch:33 Batch:360 Log-loss0.04191993549466133
# Epoch:33 Batch:400 Log-loss0.038383595645427704
# Epoch:33 Batch:440 Log-loss0.03415733575820923
# Epoch:33 Batch:480 Log-loss0.04168145731091499
# Epoch:33 Batch:520 Log-loss0.056622136384248734
# Epoch:33 Batch:560 Log-loss0.04547705873847008
# Epoch average log loss:0.03703521355387888
# In Epoch33, val_loss:0.0373681116061955, best_val_loss:0.037280518824741884, best_auc:0.9891612523457282
# Epoch:34 Batch:0 Log-loss0.035542163997888565
# Epoch:34 Batch:40 Log-loss0.05068262293934822
# Epoch:34 Batch:80 Log-loss0.029585182666778564
# Epoch:34 Batch:120 Log-loss0.03425804525613785
# Epoch:34 Batch:160 Log-loss0.04044454172253609
# Epoch:34 Batch:200 Log-loss0.03100859560072422
# Epoch:34 Batch:240 Log-loss0.03750937059521675
# Epoch:34 Batch:280 Log-loss0.03432982787489891
# Epoch:34 Batch:320 Log-loss0.04016968607902527
# Epoch:34 Batch:360 Log-loss0.04137187451124191
# Epoch:34 Batch:400 Log-loss0.039030011743307114
# Epoch:34 Batch:440 Log-loss0.03829947113990784
# Epoch:34 Batch:480 Log-loss0.037445537745952606
# Epoch:34 Batch:520 Log-loss0.03140982612967491
# Epoch:34 Batch:560 Log-loss0.0319150909781456
# Epoch average log loss:0.03708627867246313
# In Epoch34, val_loss:0.03735566996021334, best_val_loss:0.037280518824741884, best_auc:0.9891612523457282
# Epoch:35 Batch:0 Log-loss0.040992435067892075
# Epoch:35 Batch:40 Log-loss0.039444390684366226
# Epoch:35 Batch:80 Log-loss0.03171803802251816
# Epoch:35 Batch:120 Log-loss0.02853487618267536
# Epoch:35 Batch:160 Log-loss0.033874258399009705
# Epoch:35 Batch:200 Log-loss0.02402404509484768
# Epoch:35 Batch:240 Log-loss0.02929956279695034
# Epoch:35 Batch:280 Log-loss0.0454569011926651
# Epoch:35 Batch:320 Log-loss0.03148229047656059
# Epoch:35 Batch:360 Log-loss0.03766770660877228
# Epoch:35 Batch:400 Log-loss0.04817536100745201
# Epoch:35 Batch:440 Log-loss0.03583447262644768
# Epoch:35 Batch:480 Log-loss0.04011039063334465
# Epoch:35 Batch:520 Log-loss0.04511226341128349
# Epoch:35 Batch:560 Log-loss0.039899565279483795
# Epoch average log loss:0.03715980926728142
# In Epoch35, val_loss:0.037343013598350384, best_val_loss:0.037280518824741884, best_auc:0.9891612523457282
# Epoch:36 Batch:0 Log-loss0.027390748262405396
# Epoch:36 Batch:40 Log-loss0.03682770952582359
# Epoch:36 Batch:80 Log-loss0.044804323464632034
# Epoch:36 Batch:120 Log-loss0.041138533502817154
# Epoch:36 Batch:160 Log-loss0.03126450628042221
# Epoch:36 Batch:200 Log-loss0.02871652878820896
# Epoch:36 Batch:240 Log-loss0.016614744439721107
# Epoch:36 Batch:280 Log-loss0.03286256641149521
# Epoch:36 Batch:320 Log-loss0.04188508912920952
# Epoch:36 Batch:360 Log-loss0.0405288003385067
# Epoch:36 Batch:400 Log-loss0.040382370352745056
# Epoch:36 Batch:440 Log-loss0.026983385905623436
# Epoch:36 Batch:480 Log-loss0.03270965814590454
# Epoch:36 Batch:520 Log-loss0.023365361616015434
# Epoch:36 Batch:560 Log-loss0.04872070252895355
# Epoch average log loss:0.03679906792240217
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch36, val_loss:0.03722852222087956, best_val_loss:0.03722852222087956, best_auc:0.9890564514341756
# Epoch:37 Batch:0 Log-loss0.034658219665288925
# Epoch:37 Batch:40 Log-loss0.026480356231331825
# Epoch:37 Batch:80 Log-loss0.0394851379096508
# Epoch:37 Batch:120 Log-loss0.049479857087135315
# Epoch:37 Batch:160 Log-loss0.041176099330186844
# Epoch:37 Batch:200 Log-loss0.03891998529434204
# Epoch:37 Batch:240 Log-loss0.02449328638613224
# Epoch:37 Batch:280 Log-loss0.027745775878429413
# Epoch:37 Batch:320 Log-loss0.04008052125573158
# Epoch:37 Batch:360 Log-loss0.044503260403871536
# Epoch:37 Batch:400 Log-loss0.044721320271492004
# Epoch:37 Batch:440 Log-loss0.0413668192923069
# Epoch:37 Batch:480 Log-loss0.04073168337345123
# Epoch:37 Batch:520 Log-loss0.03495747968554497
# Epoch:37 Batch:560 Log-loss0.03812623769044876
# Epoch average log loss:0.036785230482928456
# In Epoch37, val_loss:0.037322914544773024, best_val_loss:0.03722852222087956, best_auc:0.9890564514341756
# Epoch:38 Batch:0 Log-loss0.027000943198800087
# Epoch:38 Batch:40 Log-loss0.04061673954129219
# Epoch:38 Batch:80 Log-loss0.05059562996029854
# Epoch:38 Batch:120 Log-loss0.03693980723619461
# Epoch:38 Batch:160 Log-loss0.03739790990948677
# Epoch:38 Batch:200 Log-loss0.03573295846581459
# Epoch:38 Batch:240 Log-loss0.04197469726204872
# Epoch:38 Batch:280 Log-loss0.029526004567742348
# Epoch:38 Batch:320 Log-loss0.03616681322455406
# Epoch:38 Batch:360 Log-loss0.049979496747255325
# Epoch:38 Batch:400 Log-loss0.031815409660339355
# Epoch:38 Batch:440 Log-loss0.04396064952015877
# Epoch:38 Batch:480 Log-loss0.023452656343579292
# Epoch:38 Batch:520 Log-loss0.03942645341157913
# Epoch:38 Batch:560 Log-loss0.038625720888376236
# Epoch average log loss:0.036995707784912416
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch38, val_loss:0.03719077182150346, best_val_loss:0.03719077182150346, best_auc:0.9890165718722078
# Epoch:39 Batch:0 Log-loss0.04016615077853203
# Epoch:39 Batch:40 Log-loss0.040844857692718506
# Epoch:39 Batch:80 Log-loss0.038754504173994064
# Epoch:39 Batch:120 Log-loss0.03784547001123428
# Epoch:39 Batch:160 Log-loss0.03219325467944145
# Epoch:39 Batch:200 Log-loss0.04241184517741203
# Epoch:39 Batch:240 Log-loss0.043886762112379074
# Epoch:39 Batch:280 Log-loss0.05087236687541008
# Epoch:39 Batch:320 Log-loss0.03512367233633995
# Epoch:39 Batch:360 Log-loss0.03659537807106972
# Epoch:39 Batch:400 Log-loss0.022997314110398293
# Epoch:39 Batch:440 Log-loss0.0248101819306612
# Epoch:39 Batch:480 Log-loss0.04040003940463066
# Epoch:39 Batch:520 Log-loss0.04615933075547218
# Epoch:39 Batch:560 Log-loss0.025107108056545258
# Epoch average log loss:0.03700028236489743
# In Epoch39, val_loss:0.03727926171658792, best_val_loss:0.03719077182150346, best_auc:0.9890165718722078
# Epoch:40 Batch:0 Log-loss0.022937921807169914
# Epoch:40 Batch:40 Log-loss0.030566314235329628
# Epoch:40 Batch:80 Log-loss0.04522509500384331
# Epoch:40 Batch:120 Log-loss0.029762016609311104
# Epoch:40 Batch:160 Log-loss0.03157923370599747
# Epoch:40 Batch:200 Log-loss0.03123619593679905
# Epoch:40 Batch:240 Log-loss0.02937442995607853
# Epoch:40 Batch:280 Log-loss0.0335443951189518
# Epoch:40 Batch:320 Log-loss0.031075915321707726
# Epoch:40 Batch:360 Log-loss0.043952494859695435
# Epoch:40 Batch:400 Log-loss0.03846026584506035
# Epoch:40 Batch:440 Log-loss0.037237461656332016
# Epoch:40 Batch:480 Log-loss0.03888985514640808
# Epoch:40 Batch:520 Log-loss0.041369106620550156
# Epoch:40 Batch:560 Log-loss0.0361940823495388
# Epoch average log loss:0.03696970444538498
# Model has been saved as temporary_checkpoints/FASTTXT_BGRU_64_64-TEMP.pt.
#
# In Epoch40, val_loss:0.037187047823038145, best_val_loss:0.037187047823038145, best_auc:0.9889335917214264
# Epoch:41 Batch:0 Log-loss0.046189576387405396
# Epoch:41 Batch:40 Log-loss0.04938426986336708
# Epoch:41 Batch:80 Log-loss0.03842392936348915
# Epoch:41 Batch:120 Log-loss0.048611417412757874
# Epoch:41 Batch:160 Log-loss0.0379195399582386
# Epoch:41 Batch:200 Log-loss0.040140461176633835
# Epoch:41 Batch:240 Log-loss0.04956863448023796
# Epoch:41 Batch:280 Log-loss0.028649361804127693
# Epoch:41 Batch:320 Log-loss0.041014574468135834
# Epoch:41 Batch:360 Log-loss0.030673174187541008
# Epoch:41 Batch:400 Log-loss0.0355849415063858
# Epoch:41 Batch:440 Log-loss0.026770837604999542
# Epoch:41 Batch:480 Log-loss0.029718542471528053
# Epoch:41 Batch:520 Log-loss0.03486945107579231
# Epoch:41 Batch:560 Log-loss0.04453378543257713
# Epoch average log loss:0.036813383070485935
# In Epoch41, val_loss:0.03725409934025623, best_val_loss:0.037187047823038145, best_auc:0.9889335917214264
# Epoch:42 Batch:0 Log-loss0.032268550246953964
# Epoch:42 Batch:40 Log-loss0.03819175437092781
# Epoch:42 Batch:80 Log-loss0.026156602427363396
# Epoch:42 Batch:120 Log-loss0.035541970282793045
# Epoch:42 Batch:160 Log-loss0.037008222192525864
# Epoch:42 Batch:200 Log-loss0.03382289037108421
# Epoch:42 Batch:240 Log-loss0.049914002418518066
# Epoch:42 Batch:280 Log-loss0.04340128228068352
# Epoch:42 Batch:320 Log-loss0.03338106349110603
# Epoch:42 Batch:360 Log-loss0.031241053715348244
# Epoch:42 Batch:400 Log-loss0.034176282584667206
# Epoch:42 Batch:440 Log-loss0.05386197194457054
# Epoch:42 Batch:480 Log-loss0.03476850688457489
# Epoch:42 Batch:520 Log-loss0.03774731606245041
# Epoch:42 Batch:560 Log-loss0.016875572502613068
# Epoch average log loss:0.03660768243051799
# In Epoch42, val_loss:0.03732168410835348, best_val_loss:0.037187047823038145, best_auc:0.9889335917214264
# Epoch:43 Batch:0 Log-loss0.03515872731804848
# Epoch:43 Batch:40 Log-loss0.026994481682777405
# Epoch:43 Batch:80 Log-loss0.03507150709629059
# Epoch:43 Batch:120 Log-loss0.052563104778528214
# Epoch:43 Batch:160 Log-loss0.04921707138419151
# Epoch:43 Batch:200 Log-loss0.02705453336238861
# Epoch:43 Batch:240 Log-loss0.03229468688368797
# Epoch:43 Batch:280 Log-loss0.03737211227416992
# Epoch:43 Batch:320 Log-loss0.0402056910097599
# Epoch:43 Batch:360 Log-loss0.03167347237467766
# Epoch:43 Batch:400 Log-loss0.03287142515182495
# Epoch:43 Batch:440 Log-loss0.03742274269461632
# Epoch:43 Batch:480 Log-loss0.03631872311234474
# Epoch:43 Batch:520 Log-loss0.028033895418047905
# Epoch:43 Batch:560 Log-loss0.03672155365347862
# Epoch average log loss:0.036791893686833124
# In Epoch43, val_loss:0.037288376450489484, best_val_loss:0.037187047823038145, best_auc:0.9889335917214264
# Epoch:44 Batch:0 Log-loss0.031550969928503036
# Epoch:44 Batch:40 Log-loss0.03381931409239769
# Epoch:44 Batch:80 Log-loss0.045408520847558975
# Epoch:44 Batch:120 Log-loss0.04696900025010109
# Epoch:44 Batch:160 Log-loss0.035124000161886215
# Epoch:44 Batch:200 Log-loss0.05058664083480835
# Epoch:44 Batch:240 Log-loss0.061946768313646317
# Epoch:44 Batch:280 Log-loss0.04035746306180954
# Epoch:44 Batch:320 Log-loss0.03693334385752678
# Epoch:44 Batch:360 Log-loss0.04026741161942482
# Epoch:44 Batch:400 Log-loss0.033640678972005844
# Epoch:44 Batch:440 Log-loss0.034867141395807266
# Epoch:44 Batch:480 Log-loss0.02929726056754589
# Epoch:44 Batch:520 Log-loss0.035537656396627426
# Epoch:44 Batch:560 Log-loss0.024604352191090584
# Epoch average log loss:0.03668963035036411
# In Epoch44, val_loss:0.03746491128825227, best_val_loss:0.037187047823038145, best_auc:0.9889335917214264
# Epoch:45 Batch:0 Log-loss0.03961610421538353
# Epoch:45 Batch:40 Log-loss0.04841339588165283
# Epoch:45 Batch:80 Log-loss0.022393397986888885
# Epoch:45 Batch:120 Log-loss0.034102603793144226
# Epoch:45 Batch:160 Log-loss0.02802799455821514
# Epoch:45 Batch:200 Log-loss0.0468687005341053
# Epoch:45 Batch:240 Log-loss0.04173804819583893
# Epoch:45 Batch:280 Log-loss0.04868317022919655
# Epoch:45 Batch:320 Log-loss0.04020778834819794
# Epoch:45 Batch:360 Log-loss0.03284776583313942
# Epoch:45 Batch:400 Log-loss0.043810080736875534
# Epoch:45 Batch:440 Log-loss0.03616361320018768
# Epoch:45 Batch:480 Log-loss0.030474631115794182
# Epoch:45 Batch:520 Log-loss0.025500783696770668
# Epoch:45 Batch:560 Log-loss0.025793680921196938
# Epoch average log loss:0.03672576240995633
# In Epoch45, val_loss:0.03736899266467802, best_val_loss:0.037187047823038145, best_auc:0.9889335917214264
# Epoch:46 Batch:0 Log-loss0.029167594388127327
# Epoch:46 Batch:40 Log-loss0.03613545373082161
# Epoch:46 Batch:80 Log-loss0.027204664424061775
# Epoch:46 Batch:120 Log-loss0.03930847346782684
# Epoch:46 Batch:160 Log-loss0.03739314153790474
# Epoch:46 Batch:200 Log-loss0.0395079143345356
# Epoch:46 Batch:240 Log-loss0.05430882051587105
# Epoch:46 Batch:280 Log-loss0.04689684510231018
# Epoch:46 Batch:320 Log-loss0.039858344942331314
# Epoch:46 Batch:360 Log-loss0.035380978137254715
# Epoch:46 Batch:400 Log-loss0.03116876445710659
# Epoch:46 Batch:440 Log-loss0.03970806673169136
# Epoch:46 Batch:480 Log-loss0.03346617892384529
# Epoch:46 Batch:520 Log-loss0.03172599896788597
# Epoch:46 Batch:560 Log-loss0.048927102237939835
# Epoch average log loss:0.03674454153182783
# In Epoch46, val_loss:0.037268073350224924, best_val_loss:0.037187047823038145, best_auc:0.9889335917214264
# Epoch:47 Batch:0 Log-loss0.028306225314736366
# Epoch:47 Batch:40 Log-loss0.04166557639837265
# Epoch:47 Batch:80 Log-loss0.02781062014400959
# Epoch:47 Batch:120 Log-loss0.042322877794504166
# Epoch:47 Batch:160 Log-loss0.03688504919409752
# Epoch:47 Batch:200 Log-loss0.02853623777627945
# Epoch:47 Batch:240 Log-loss0.03474757447838783
# Epoch:47 Batch:280 Log-loss0.05562729761004448
# Epoch:47 Batch:320 Log-loss0.03748201206326485
# Epoch:47 Batch:360 Log-loss0.031562112271785736
# Epoch:47 Batch:400 Log-loss0.04009081795811653

# %% [markdown]
# ## Make predections

# %%
import numpy as np
from sklearn.metrics import roc_auc_score

train_fold_preditcions = np.concatenate(best_val_pred, axis=0)
training_auc = roc_auc_score(training_labels, train_fold_preditcions)
print("Training AUC", training_auc)

# %%
import pandas as pd
path = 'Dataset/'
TRAIN_DATA_FILE=path + 'train.csv'
TEST_DATA_FILE=path + 'test.csv'
test_df = pd.read_csv(TEST_DATA_FILE)
train_df = pd.read_csv(TRAIN_DATA_FILE)

# %%
CLASSES = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
submit_path_prefix = "results/bgru/Fasttext-BGRU-" + str(MAX_SEQUENCE_LENGTH) 

print("Predicting testing results...")
test_predicts_list = []
for fold_id, model in enumerate(new_models):
    test_predicts = model.predict(test_sequences, batch_size=256, verbose=1)
    test_predicts_list.append(test_predicts)

test_predicts = np.zeros(test_predicts_list[0].shape)
for fold_predict in test_predicts_list:
    test_predicts += fold_predict
test_predicts /= len(test_predicts_list)

test_ids = test_df["id"].values
test_ids = test_ids.reshape((len(test_ids), 1))

test_predicts = pd.DataFrame(data=test_predicts, columns=CLASSES)
test_predicts["id"] = test_ids
test_predicts = test_predicts[["id"] + CLASSES]

# %%
submit_path = submit_path_prefix + "-L{:4f}-A{:4f}.csv".format(best_logloss, best_auc)
test_predicts.to_csv(submit_path, index=False)

# %%
print("Predicting training results...")

train_ids = train_df["id"].values
train_ids = train_ids.reshape((len(train_ids), 1))

train_predicts = pd.DataFrame(data=train_fold_preditcions, columns=CLASSES)
train_predicts["id"] = train_ids
train_predicts = train_predicts[["id"] + CLASSES]
submit_path = submit_path_prefix + "-Train-L{:4f}-A{:4f}.csv".format(best_logloss, best_auc)
train_predicts.to_csv(submit_path, index=False)
